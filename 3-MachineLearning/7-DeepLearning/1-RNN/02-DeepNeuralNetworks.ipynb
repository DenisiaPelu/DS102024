# %% [markdown]
# # **Entrenamiento de redes neuronales profundas**

# %% [markdown]
# # Problema de los degradados que desaparecen/explotan

# %% [markdown]
# Observando la función de activación sigmoidea, se puede ver que cuando las entradas son grandes (negativas o positivas), la función se satura en 0 o 1, con una derivada extremadamente cercana a 0 (es decir, la curva es plana en ambos extremos). Por lo tanto, cuando el backpropagation se pone en marcha, prácticamente no tiene gradiente para propagarse a través de la red, y el poco gradiente que existe se va diluyendo a medida que la backpropagation avanza a través de las capas superiores, por lo que realmente no queda nada para las capas inferiores.

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

def sigmoid(z):
    return 1 / (1 + np.exp(-z))

z = np.linspace(-5, 5, 200)

plt.plot([-5, 5], [0, 0], 'k-')
plt.plot([-5, 5], [1, 1], 'k--')
plt.plot([0, 0], [-0.2, 1.2], 'k-')
plt.plot([-5, 5], [-3/4, 7/4], 'g--')
plt.plot(z, sigmoid(z), "b-", linewidth=2,
         label=r"$\sigma(z) = \dfrac{1}{1+e^{-z}}$")
props = dict(facecolor='black', shrink=0.1)
plt.annotate('Saturating', xytext=(3.5, 0.7), xy=(5, 1), arrowprops=props,
             fontsize=14, ha="center")
plt.annotate('Saturating', xytext=(-3.5, 0.3), xy=(-5, 0), arrowprops=props,
             fontsize=14, ha="center")
plt.annotate('Linear', xytext=(2, 0.2), xy=(0, 0.5), arrowprops=props,
             fontsize=14, ha="center")
plt.grid(True)
plt.axis([-5, 5, -0.2, 1.2])
plt.xlabel("$z$")
plt.legend(loc="upper left", fontsize=16)

plt.show()

# %% [markdown]
# ## Xavier and He Initialization

# %%
dense = tf.keras.layers.Dense(50, activation="relu",
                              kernel_initializer="he_normal")

# %%
he_avg_init = tf.keras.initializers.VarianceScaling(scale=2., mode="fan_avg",
                                                    distribution="uniform")
dense = tf.keras.layers.Dense(50, activation="sigmoid",
                              kernel_initializer=he_avg_init)

# %% [markdown]
# ## Nonsaturating Activation Functions

# %% [markdown]
# ### Leaky ReLU

# %% [markdown]
# La función de activación ReLU se define como $LeakyReLU_α (z) = max(αz, z)$. El hiperparámetro α define el grado de "fuga" de la función: es la pendiente de la función para z < 0. Tener una pendiente para z < 0 garantiza que las ReLU con fugas nunca mueran; pueden entrar en un coma prolongado, pero tienen la oportunidad de despertar. Un artículo de 2015 de Bing Xu et al. comparaba diversas variantes de la función de activación ReLU, y una de sus conclusiones era que las variantes con fugas siempre superaban a la función de activación ReLU estricta. De hecho, establecer α = 0,2 (una fuga enorme) parecía dar como resultado un mejor rendimiento que α = 0,01 (una fuga pequeña). El artículo también evaluaba la función ReLU aleatoria con fugas (RReLU), en la que α se elige aleatoriamente en un rango determinado durante el entrenamiento y se fija en un valor medio durante las pruebas. RReLU también funcionó bastante bien y pareció actuar como regularizador, reduciendo el riesgo de sobreajuste del conjunto de entrenamiento. Por último, se evaluó el ReLU paramétrico con fugas (PReLU), en el que se autoriza el aprendizaje de α durante el entrenamiento: en lugar de ser un hiperparámetro, se convierte en un parámetro que puede modificarse mediante backpropagation como cualquier otro parámetro. Según los informes, PReLU supera ampliamente a ReLU en grandes conjuntos de datos de imágenes, pero en conjuntos de datos más pequeños corre el riesgo de sobreajustar el conjunto de entrenamiento.

# %%
def leaky_relu(z, alpha):
    return np.maximum(alpha * z, z)

z = np.linspace(-5, 5, 200)
plt.plot(z, leaky_relu(z, 0.1), "b-", linewidth=2, label=r"$LeakyReLU(z) = max(\alpha z, z)$")
plt.plot([-5, 5], [0, 0], 'k-')
plt.plot([0, 0], [-1, 3.7], 'k-')
plt.grid(True)
props = dict(facecolor='black', shrink=0.1)
plt.annotate('Leak', xytext=(-3.5, 0.5), xy=(-5, -0.3), arrowprops=props,
             fontsize=14, ha="center")
plt.xlabel("$z$")
plt.axis([-5, 5, -1, 3.7])
plt.gca().set_aspect("equal")
plt.legend()

plt.show()

# %%
leaky_relu = tf.keras.layers.LeakyReLU(negative_slope=0.2)
dense = tf.keras.layers.Dense(50, activation=leaky_relu,
                              kernel_initializer="he_normal")

# %%
model = tf.keras.models.Sequential([
    # [...]  # more layers
    tf.keras.layers.Dense(50, kernel_initializer="he_normal"),
    tf.keras.layers.LeakyReLU(alpha=0.2), 
    # [...]  # more layers
])
# Out:
# c:\Users\denis\Desktop\Curso\Juan-Temario\DS102024_2025\3-MachineLearning\7-DeepLearning\.venv\Lib\site-packages\keras\src\layers\activations\leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %% [markdown]
# ### ELU

# %% [markdown]
# Implementar ELU en TensorFlow es trivial, basta con especificar la función de activación al construir cada capa, y utilizar He inicialización:

# %%
dense = tf.keras.layers.Dense(50, activation="elu",
                              kernel_initializer="he_normal")

# %% [markdown]
# ### SELU

# %% [markdown]
# Por defecto, los hiperparámetros de SELU (`scale` y `alpha`) se ajustan de tal forma que la media de salida de cada neurona se mantiene cercana a 0, y la desviación estándar se mantiene cercana a 1 (asumiendo que las entradas están estandarizadas con media 0 y desviación estándar 1 también, y se respetan otras restricciones). Usando esta función de activación, incluso una red neuronal profunda de 1.000 capas conserva aproximadamente la media 0 y la desviación estándar 1 en todas las capas, evitando el problema de la explosión/desvanecimiento de gradientes:

# %%
from scipy.special import erfc

# alfa y scale para auto normalizar con media 0 y desviación estándar 1
alpha_0_1 = -np.sqrt(2 / np.pi) / (erfc(1 / np.sqrt(2)) * np.exp(1 / 2) - 1)
scale_0_1 = (
    (1 - erfc(1 / np.sqrt(2)) * np.sqrt(np.e))
    * np.sqrt(2 * np.pi)
    * (
        2 * erfc(np.sqrt(2)) * np.e ** 2
        + np.pi * erfc(1 / np.sqrt(2)) ** 2 * np.e
        - 2 * (2 + np.pi) * erfc(1 / np.sqrt(2)) * np.sqrt(np.e)
        + np.pi
        + 2
    ) ** (-1 / 2)
)

def elu(z, alpha=1):
    return np.where(z < 0, alpha * (np.exp(z) - 1), z)

def selu(z, scale=scale_0_1, alpha=alpha_0_1):
    return scale * elu(z, alpha)

z = np.linspace(-5, 5, 200)
plt.plot(z, elu(z), "b-", linewidth=2, label=r"ELU$_\alpha(z) = \alpha (e^z - 1)$ if $z < 0$, else $z$")
plt.plot(z, selu(z), "r--", linewidth=2, label=r"SELU$(z) = 1.05 \, $ELU$_{1.67}(z)$")
plt.plot([-5, 5], [0, 0], 'k-')
plt.plot([-5, 5], [-1, -1], 'k:', linewidth=2)
plt.plot([-5, 5], [-1.758, -1.758], 'k:', linewidth=2)
plt.plot([0, 0], [-2.2, 3.2], 'k-')
plt.grid(True)
plt.axis([-5, 5, -2.2, 3.2])
plt.xlabel("$z$")
plt.gca().set_aspect("equal")
plt.legend()

plt.show()

# %% [markdown]
# Utilizar SELU es muy sencillo:

# %%
dense = tf.keras.layers.Dense(50, activation="selu",
                              kernel_initializer="lecun_normal")

# %% [markdown]
# **Material extra: ejemplo de red autorregularizada con SELU**.
#
# Vamos a crear una red neuronal para la Moda MNIST con 100 capas ocultas, utilizando la función de activación SELU:

# %%
tf.random.set_seed(42)
model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=[28, 28]))
for layer in range(100):
    model.add(tf.keras.layers.Dense(100, activation="selu",
                                    kernel_initializer="lecun_normal"))
model.add(tf.keras.layers.Dense(10, activation="softmax"))
# Out:
# c:\Users\denis\Desktop\Curso\Juan-Temario\DS102024_2025\3-MachineLearning\7-DeepLearning\.venv\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
              metrics=["accuracy"])

# %% [markdown]
# Ahora vamos a entrenarlo. No olvides escalar las entradas a media 0 y desviación típica 1:

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist.load_data()
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist
X_train, y_train = X_train_full[:-5000], y_train_full[:-5000]
X_valid, y_valid = X_train_full[-5000:], y_train_full[-5000:]
X_train, X_valid, X_test = X_train / 255, X_valid / 255, X_test / 255

# %%
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat",
               "Sandal", "Shirt", "Sneaker", "Bag", "Ankle boot"]

# %%
pixel_means = X_train.mean(axis=0, keepdims=True)
pixel_stds = X_train.std(axis=0, keepdims=True)
X_train_scaled = (X_train - pixel_means) / pixel_stds
X_valid_scaled = (X_valid - pixel_means) / pixel_stds
X_test_scaled = (X_test - pixel_means) / pixel_stds

# %%
history = model.fit(X_train_scaled, y_train, epochs=5,
                    validation_data=(X_valid_scaled, y_valid))
# Out:
# Epoch 1/5
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.4008 - loss: 1.5461 - val_accuracy: 0.5224 - val_loss: 1.2146
# Epoch 2/5
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.6241 - loss: 0.9783 - val_accuracy: 0.6752 - val_loss: 0.8097
# Epoch 3/5
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7291 - loss: 0.7306 - val_accuracy: 0.7554 - val_loss: 0.6924
# Epoch 4/5
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7739 - loss: 0.6243 - val_accuracy: 0.8076 - val_loss: 0.5664
# Epoch 5/5
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7985 - loss: 0.5638 - val_accuracy: 0.8028 - val_loss: 0.5410

# %% [markdown]
# La red ha conseguido aprender, a pesar de lo profunda que es. Ahora mira lo que ocurre si intentamos utilizar la función de activación ReLU en su lugar:

# %%
tf.random.set_seed(42)

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=[28, 28]))
for layer in range(100):
    model.add(tf.keras.layers.Dense(100, activation="relu",
                                    kernel_initializer="he_normal"))
model.add(tf.keras.layers.Dense(10, activation="softmax"))

# %%
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
              metrics=["accuracy"])

# %%
history = model.fit(X_train_scaled, y_train, epochs=5,
                    validation_data=(X_valid_scaled, y_valid))
# Out:
# Epoch 1/5
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.1643 - loss: 2.1411 - val_accuracy: 0.3570 - val_loss: 1.5311
# Epoch 2/5
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.3839 - loss: 1.4680 - val_accuracy: 0.5162 - val_loss: 1.2010
# Epoch 3/5
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.5380 - loss: 1.1023 - val_accuracy: 0.6034 - val_loss: 1.0240
# Epoch 4/5
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.5953 - loss: 0.9955 - val_accuracy: 0.6132 - val_loss: 0.9333
# Epoch 5/5
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.6414 - loss: 0.8773 - val_accuracy: 0.5010 - val_loss: 1.2282

# %% [markdown]
# No es genial en absoluto, sufrimos el problema de los gradientes que se desvanecen/explotan.

# %% [markdown]
# ### GELU, Swish and Mish

# %%
def swish(z, beta=1):
    return z * sigmoid(beta * z)

def approx_gelu(z):
    return swish(z, beta=1.702)

def softplus(z):
    return np.log(1 + np.exp(z))

def mish(z):
    return z * np.tanh(softplus(z))

z = np.linspace(-4, 2, 200)

beta = 0.6
plt.plot(z, approx_gelu(z), "b-", linewidth=2,
         label=r"GELU$(z) = z\,\Phi(z)$")
plt.plot(z, swish(z), "r--", linewidth=2,
         label=r"Swish$(z) = z\,\sigma(z)$")
plt.plot(z, swish(z, beta), "r:", linewidth=2,
         label=fr"Swish$_{{\beta={beta}}}(z)=z\,\sigma({beta}\,z)$")
plt.plot(z, mish(z), "g:", linewidth=3,
         label=fr"Mish$(z) = z\,\tanh($softplus$(z))$")
plt.plot([-4, 2], [0, 0], 'k-')
plt.plot([0, 0], [-2.2, 3.2], 'k-')
plt.grid(True)
plt.axis([-4, 2, -1, 2])
plt.gca().set_aspect("equal")
plt.xlabel("$z$")
plt.legend(loc="upper left")

plt.show()

# %% [markdown]
# # Batch Normalization

# %% [markdown]
# Aunque el uso de la inicialización He junto con ReLU (o cualquiera de sus variantes) puede reducir significativamente el peligro de los problemas de gradientes desvanecidos/explosivos al principio del entrenamiento, no garantiza que no vuelvan a aparecer durante el entrenamiento.
#
# En un artículo de 2015, 12 Sergey Ioffe y Christian Szegedy propusieron una técnica llamada normalización por lotes (BN) que aborda estos problemas. La técnica consiste en añadir una operación en el modelo justo antes o después de la función de activación de cada capa oculta. Esta operación simplemente centra en cero y normaliza cada entrada, luego escala y desplaza el resultado utilizando dos nuevos vectores de parámetros por capa: uno para la escala y otro para el desplazamiento. En otras palabras, la operación permite al modelo aprender la escala y la media óptimas de cada una de las entradas de la capa. En muchos casos, si se añade una capa BN como primera capa de la red neuronal, no es necesario estandarizar el conjunto de entrenamiento. Es decir, no hay necesidad de StandardScaler o Normalization; la capa BN lo hará por usted (bueno, aproximadamente, ya que sólo mira un lote a la vez, y también puede reescalar y desplazar cada característica de entrada).
#
# Para centrar a cero y normalizar las entradas, el algoritmo necesita estimar la media y la desviación estándar de cada entrada. Para ello, evalúa la media y la desviación estándar de la entrada en el minilote actual (de ahí el nombre de "normalización por lotes").

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(42)
# Out:
# WARNING:tensorflow:From c:\Users\denis\Desktop\Curso\Juan-Temario\DS102024_2025\3-MachineLearning\7-DeepLearning\.venv\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(300, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Dense(10, activation="softmax")
])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 784)            │         3,136 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 300)            │       235,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 300)            │         1,200 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 100)            │        30,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 100)            │           400 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 271,346 (1.04 MB)
#  Trainable params: 268,978 (1.03 MB)
#  Non-trainable params: 2,368 (9.25 KB)

# %%
[(var.name, var.trainable) for var in model.layers[1].variables]
# Out:
# [('gamma', True),
#  ('beta', True),
#  ('moving_mean', False),
#  ('moving_variance', False)]

# %%
# sólo demuestran que el modelo funciona 😊
model.compile(loss="sparse_categorical_crossentropy", optimizer="sgd",
              metrics=["accuracy"])
model.fit(X_train, y_train, epochs=2, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/2
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7618 - loss: 0.7042 - val_accuracy: 0.8516 - val_loss: 0.4010
# Epoch 2/2
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8567 - loss: 0.4028 - val_accuracy: 0.8634 - val_loss: 0.3662

# %% [markdown]
# A veces aplicar BN antes de la función de activación funciona mejor (hay un debate sobre este tema). Por otra parte, la capa antes de una capa `BatchNormalization` no necesita tener términos de sesgo, ya que la capa `BatchNormalization` algunos también, sería un desperdicio de parámetros, por lo que puede establecer `use_bias=False` al crear esas capas:

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(42)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    tf.keras.layers.Dense(300, kernel_initializer="he_normal", use_bias=False),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation("relu"),
    tf.keras.layers.Dense(100, kernel_initializer="he_normal", use_bias=False),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Activation("relu"),
    tf.keras.layers.Dense(10, activation="softmax")
])

# %%
model.compile(loss="sparse_categorical_crossentropy", optimizer="sgd",
              metrics=["accuracy"])
model.fit(X_train, y_train, epochs=2, validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/2
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7413 - loss: 0.7832 - val_accuracy: 0.8410 - val_loss: 0.4313
# Epoch 2/2
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8493 - loss: 0.4360 - val_accuracy: 0.8560 - val_loss: 0.3934

# %% [markdown]
# ## Gradient Clipping

# %% [markdown]
# Otra técnica para mitigar el problema de la explosión de gradientes es recortar los gradientes durante la backpropagation para que nunca superen algún umbral. Esta técnica se utiliza generalmente en redes neuronales recurrentes, donde el uso de la normalización por lotes es complicado.

# %% [markdown]
# Todos los `tf.keras.optimizers` aceptan argumentos `clipnorm` o `clipvalue`:

# %%
optimizer = tf.keras.optimizers.SGD(clipvalue=1.0)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer)

# %%
optimizer = tf.keras.optimizers.SGD(clipnorm=1.0)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer)

# %% [markdown]
# ## Reutilización de capas preentrenadas

# %% [markdown]
# ### Reusing a Keras model

# %% [markdown]
# Vamos a dividir el conjunto de entrenamiento MNIST de moda en dos:
# * X_train_A: todas las imágenes de todos los artículos excepto camisetas y jerseys (clases 0 y 2).
# * X_train_B": un conjunto de entrenamiento mucho más pequeño, con sólo las 200 primeras imágenes de camisetas y jerseys.
#
# El conjunto de validación y el conjunto de prueba también se dividen de esta forma, pero sin restringir el número de imágenes.
#
# Entrenaremos un modelo en el conjunto A (tarea de clasificación con 8 clases), e intentaremos reutilizarlo para abordar el conjunto B (clasificación binaria). Esperamos transferir un poco de conocimiento de la tarea A a la tarea B, ya que las clases del conjunto A (pantalones, vestidos, abrigos, sandalias, camisas, zapatillas, bolsos y botines) son algo similares a las clases del conjunto B (camisetas/tops y jerseys). Sin embargo, como estamos utilizando capas "densas", sólo pueden reutilizarse los patrones que aparecen en el mismo lugar.

# %%
# dividir Fashion MNIST en tareas A y B, luego entrenar y guardar
# el modelo A en "mi_modelo_A".

pos_class_id = class_names.index("Pullover")
neg_class_id = class_names.index("T-shirt/top")

def split_dataset(X, y):
    y_for_B = (y == pos_class_id) | (y == neg_class_id)
    y_A = y[~y_for_B]
    y_B = (y[y_for_B] == pos_class_id).astype(np.float32)
    old_class_ids = list(set(range(10)) - set([neg_class_id, pos_class_id]))
    for old_class_id, new_class_id in zip(old_class_ids, range(8)):
        y_A[y_A == old_class_id] = new_class_id  # reorder class ids for A
    return ((X[~y_for_B], y_A), (X[y_for_B], y_B))

(X_train_A, y_train_A), (X_train_B, y_train_B) = split_dataset(X_train, y_train)
(X_valid_A, y_valid_A), (X_valid_B, y_valid_B) = split_dataset(X_valid, y_valid)
(X_test_A, y_test_A), (X_test_B, y_test_B) = split_dataset(X_test, y_test)
X_train_B = X_train_B[:200]
y_train_B = y_train_B[:200]

tf.random.set_seed(42)

model_A = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dense(8, activation="softmax")
])

model_A.compile(loss="sparse_categorical_crossentropy",
                optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
                metrics=["accuracy"])
history = model_A.fit(X_train_A, y_train_A, epochs=20,
                      validation_data=(X_valid_A, y_valid_A))
model_A.save("my_model_A.keras")
# Out:
# Epoch 1/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 2s 965us/step - accuracy: 0.4755 - loss: 1.5547 - val_accuracy: 0.7982 - val_loss: 0.6826
# Epoch 2/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 1s 907us/step - accuracy: 0.8104 - loss: 0.6312 - val_accuracy: 0.8373 - val_loss: 0.5008
# Epoch 3/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 1s 922us/step - accuracy: 0.8480 - loss: 0.4868 - val_accuracy: 0.8634 - val_loss: 0.4284
# Epoch 4/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 1s 913us/step - accuracy: 0.8665 - loss: 0.4201 - val_accuracy: 0.8716 - val_loss: 0.3880
# Epoch 5/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 1s 896us/step - accuracy: 0.8752 - loss: 0.3805 - val_accuracy: 0.8782 - val_loss: 0.3622
# Epoch 6/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 1s 906us/step - accuracy: 0.8813 - loss: 0.3546 - val_accuracy: 0.8814 - val_loss: 0.3448
# Epoch 7/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 1s 896us/step - accuracy: 0.8871 - loss: 0.3363 - val_accuracy: 0.8857 - val_loss: 0.3319
# Epoch 8/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 1s 886us/step - accuracy: 0.8912 - loss: 0.3226 - val_accuracy: 0.8877 - val_loss: 0.3219
# Epoch 9/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 1s 930us/step - accuracy: 0.8936 - loss: 0.3117 - val_accuracy: 0.8889 - val_loss: 0.3137
# Epoch 10/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 1s 964us/step - accuracy: 0.8957 - loss: 0.3027 - val_accuracy: 0.8915 - val_loss: 0.3068
# Epoch 11/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8981 - loss: 0.2951 - val_accuracy: 0.8917 - val_loss: 0.3009
# Epoch 12/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 1s 909us/step - accuracy: 0.9001 - loss: 0.2884 - val_accuracy: 0.8965 - val_loss: 0.2956
# Epoch 13/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 1s 895us/step - accuracy: 0.9017 - loss: 0.2825 - val_accuracy: 0.8975 - val_loss: 0.2910
# Epoch 14/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 1s 893us/step - accuracy: 0.9035 - loss: 0.2771 - val_accuracy: 0.8995 - val_loss: 0.2868
# Epoch 15/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 1s 891us/step - accuracy: 0.9054 - loss: 0.2723 - val_accuracy: 0.9012 - val_loss: 0.2829
# Epoch 16/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 1s 871us/step - accuracy: 0.9073 - loss: 0.2678 - val_accuracy: 0.9025 - val_loss: 0.2794
# Epoch 17/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 1s 874us/step - accuracy: 0.9088 - loss: 0.2636 - val_accuracy: 0.9042 - val_loss: 0.2760
# Epoch 18/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 1s 910us/step - accuracy: 0.9100 - loss: 0.2598 - val_accuracy: 0.9057 - val_loss: 0.2731
# Epoch 19/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 1s 885us/step - accuracy: 0.9111 - loss: 0.2561 - val_accuracy: 0.9065 - val_loss: 0.2702
# Epoch 20/20
# 1376/1376 ━━━━━━━━━━━━━━━━━━━━ 1s 867us/step - accuracy: 0.9119 - loss: 0.2527 - val_accuracy: 0.9070 - val_loss: 0.2672

# %%
# entrenar y evaluar el modelo B, sin reutilizar el modelo A

tf.random.set_seed(42)
model_B = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

model_B.compile(loss="binary_crossentropy",
                optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
                metrics=["accuracy"])
history = model_B.fit(X_train_B, y_train_B, epochs=20,
                      validation_data=(X_valid_B, y_valid_B))
model_B.evaluate(X_test_B, y_test_B)
# Out:
# Epoch 1/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.4350 - loss: 0.7493 - val_accuracy: 0.4866 - val_loss: 0.6956
# Epoch 2/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4369 - loss: 0.7003 - val_accuracy: 0.4926 - val_loss: 0.6620
# Epoch 3/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4574 - loss: 0.6625 - val_accuracy: 0.5391 - val_loss: 0.6348
# Epoch 4/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.5079 - loss: 0.6322 - val_accuracy: 0.6360 - val_loss: 0.6118
# Epoch 5/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6918 - loss: 0.6069 - val_accuracy: 0.7587 - val_loss: 0.5916
# Epoch 6/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.7892 - loss: 0.5849 - val_accuracy: 0.8170 - val_loss: 0.5736
# Epoch 7/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8368 - loss: 0.5653 - val_accuracy: 0.8487 - val_loss: 0.5571
# Epoch 8/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8757 - loss: 0.5477 - val_accuracy: 0.8754 - val_loss: 0.5421
# Epoch 9/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9011 - loss: 0.5312 - val_accuracy: 0.8902 - val_loss: 0.5278
# Epoch 10/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9169 - loss: 0.5154 - val_accuracy: 0.8991 - val_loss: 0.5144
# Epoch 11/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9257 - loss: 0.5005 - val_accuracy: 0.9070 - val_loss: 0.5016
# Epoch 12/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9257 - loss: 0.4863 - val_accuracy: 0.9159 - val_loss: 0.4893
# Epoch 13/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9345 - loss: 0.4730 - val_accuracy: 0.9159 - val_loss: 0.4777
# Epoch 14/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9345 - loss: 0.4605 - val_accuracy: 0.9228 - val_loss: 0.4665
# Epoch 15/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9345 - loss: 0.4486 - val_accuracy: 0.9228 - val_loss: 0.4558
# Epoch 16/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9345 - loss: 0.4371 - val_accuracy: 0.9228 - val_loss: 0.4454
# Epoch 17/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9454 - loss: 0.4260 - val_accuracy: 0.9268 - val_loss: 0.4355
# Epoch 18/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9562 - loss: 0.4155 - val_accuracy: 0.9278 - val_loss: 0.4260
# Epoch 19/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9562 - loss: 0.4054 - val_accuracy: 0.9288 - val_loss: 0.4171
# Epoch 20/20
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9562 - loss: 0.3960 - val_accuracy: 0.9288 - val_loss: 0.4085
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step - accuracy: 0.9211 - loss: 0.4155
# [0.41867151856422424, 0.9185000061988831]

# %% [markdown]
# El modelo B alcanza una precisión del 91,85% en el conjunto de pruebas. Ahora vamos a intentar reutilizar el modelo A preentrenado.

# %%
model_A = tf.keras.models.load_model("my_model_A.keras")
model_B_on_A = tf.keras.Sequential(model_A.layers[:-1])
model_B_on_A.add(tf.keras.layers.Dense(1, activation="sigmoid"))

# %% [markdown]
# Ten en cuenta que `model_B_on_A` y `model_A` comparten capas ahora, así que cuando entrenemos uno, se actualizarán ambos modelos. Si queremos evitar esto, tenemos que construir "model_B_on_A" sobre un "clon" de "model_A":

# %%
tf.random.set_seed(42)

# %%
model_A_clone = tf.keras.models.clone_model(model_A)
model_A_clone.set_weights(model_A.get_weights())

# %%
# crear modelo_B_on_A igual que en la celda anterior
model_B_on_A = tf.keras.Sequential(model_A_clone.layers[:-1])
model_B_on_A.add(tf.keras.layers.Dense(1, activation="sigmoid"))

# %%
for layer in model_B_on_A.layers[:-1]:
    layer.trainable = False

optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)
model_B_on_A.compile(loss="binary_crossentropy", optimizer=optimizer,
                     metrics=["accuracy"])

# %%
history = model_B_on_A.fit(X_train_B, y_train_B, epochs=4,
                           validation_data=(X_valid_B, y_valid_B))

for layer in model_B_on_A.layers[:-1]:
    layer.trainable = True

optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)
model_B_on_A.compile(loss="binary_crossentropy", optimizer=optimizer,
                     metrics=["accuracy"])
history = model_B_on_A.fit(X_train_B, y_train_B, epochs=16,
                           validation_data=(X_valid_B, y_valid_B))
# Out:
# Epoch 1/4
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.4371 - loss: 0.8894 - val_accuracy: 0.5321 - val_loss: 0.6848
# Epoch 2/4
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5291 - loss: 0.7039 - val_accuracy: 0.5994 - val_loss: 0.6479
# Epoch 3/4
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5530 - loss: 0.6677 - val_accuracy: 0.6261 - val_loss: 0.6350
# Epoch 4/4
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6135 - loss: 0.6529 - val_accuracy: 0.6459 - val_loss: 0.6251
# Epoch 1/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.6501 - loss: 0.6290 - val_accuracy: 0.7102 - val_loss: 0.5695
# Epoch 2/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7502 - loss: 0.5688 - val_accuracy: 0.7844 - val_loss: 0.5223
# Epoch 3/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8373 - loss: 0.5183 - val_accuracy: 0.8239 - val_loss: 0.4854
# Epoch 4/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8906 - loss: 0.4788 - val_accuracy: 0.8595 - val_loss: 0.4559
# Epoch 5/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9012 - loss: 0.4472 - val_accuracy: 0.8754 - val_loss: 0.4317
# Epoch 6/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9108 - loss: 0.4211 - val_accuracy: 0.8882 - val_loss: 0.4109
# Epoch 7/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9108 - loss: 0.3987 - val_accuracy: 0.8952 - val_loss: 0.3931
# Epoch 8/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9108 - loss: 0.3796 - val_accuracy: 0.9050 - val_loss: 0.3774
# Epoch 9/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9171 - loss: 0.3629 - val_accuracy: 0.9100 - val_loss: 0.3635
# Epoch 10/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9190 - loss: 0.3481 - val_accuracy: 0.9139 - val_loss: 0.3510
# Epoch 11/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9298 - loss: 0.3348 - val_accuracy: 0.9219 - val_loss: 0.3397
# Epoch 12/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9325 - loss: 0.3227 - val_accuracy: 0.9258 - val_loss: 0.3294
# Epoch 13/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9394 - loss: 0.3118 - val_accuracy: 0.9268 - val_loss: 0.3200
# Epoch 14/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9394 - loss: 0.3018 - val_accuracy: 0.9298 - val_loss: 0.3113
# Epoch 15/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9467 - loss: 0.2925 - val_accuracy: 0.9298 - val_loss: 0.3033
# Epoch 16/16
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9467 - loss: 0.2841 - val_accuracy: 0.9327 - val_loss: 0.2959

# %% [markdown]
# ¿Cuál es el veredicto final?

# %%
model_B_on_A.evaluate(X_test_B, y_test_B)
# Out:
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 864us/step - accuracy: 0.9292 - loss: 0.2950
# [0.2985632121562958, 0.925000011920929]

# %% [markdown]
# Estupendo. Conseguimos un poco de transferencia: la precisión del modelo subió 2 puntos porcentuales, del 91,85% al 93,85%. Esto significa que la tasa de error bajó casi un 25%:

# %%
1 - (100 - 93.85) / (100 - 91.85)
# Out:
# 0.24539877300613477

# %% [markdown]
# # Faster Optimizers

# %% [markdown]
# Entrenar una red neuronal profunda muy grande puede ser dolorosamente lento. Hasta ahora hemos visto cuatro formas de acelerar el entrenamiento (y alcanzar una solución mejor): aplicar una buena estrategia de inicialización para los pesos de conexión, usar una buena función de activación, usar normalización por lotes y reutilizar partes de una red preentrenada (posiblemente construida para una tarea auxiliar o usando aprendizaje no supervisado). Otro enorme aumento de la velocidad se consigue utilizando un optimizador más rápido que el optimizador normal de descenso de gradiente. En esta sección presentaremos los algoritmos de optimización más populares: momentum, gradiente acelerado de Nesterov, AdaGrad, RMSProp y, por último, Adam y sus variantes.

# %%
# extra code - una pequeña función para probar un optimizador en Fashion MNIST

def build_model(seed=42):
    tf.random.set_seed(seed)
    return tf.keras.Sequential([
        tf.keras.layers.Flatten(input_shape=[28, 28]),
        tf.keras.layers.Dense(100, activation="relu",
                              kernel_initializer="he_normal"),
        tf.keras.layers.Dense(100, activation="relu",
                              kernel_initializer="he_normal"),
        tf.keras.layers.Dense(100, activation="relu",
                              kernel_initializer="he_normal"),
        tf.keras.layers.Dense(10, activation="softmax")
    ])

def build_and_train_model(optimizer):
    model = build_model()
    model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
                  metrics=["accuracy"])
    return model.fit(X_train, y_train, epochs=10,
                     validation_data=(X_valid, y_valid))

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9)

# %%
history_sgd = build_and_train_model(optimizer)
# Out:
# Epoch 1/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6836 - loss: 0.9461 - val_accuracy: 0.8176 - val_loss: 0.5010
# Epoch 2/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 951us/step - accuracy: 0.8310 - loss: 0.4827 - val_accuracy: 0.8372 - val_loss: 0.4450
# Epoch 3/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 942us/step - accuracy: 0.8498 - loss: 0.4284 - val_accuracy: 0.8496 - val_loss: 0.4121
# Epoch 4/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 920us/step - accuracy: 0.8593 - loss: 0.3977 - val_accuracy: 0.8540 - val_loss: 0.3954
# Epoch 5/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 981us/step - accuracy: 0.8661 - loss: 0.3768 - val_accuracy: 0.8596 - val_loss: 0.3871
# Epoch 6/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 947us/step - accuracy: 0.8716 - loss: 0.3604 - val_accuracy: 0.8626 - val_loss: 0.3787
# Epoch 7/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 917us/step - accuracy: 0.8757 - loss: 0.3469 - val_accuracy: 0.8646 - val_loss: 0.3713
# Epoch 8/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 911us/step - accuracy: 0.8791 - loss: 0.3351 - val_accuracy: 0.8674 - val_loss: 0.3681
# Epoch 9/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 905us/step - accuracy: 0.8821 - loss: 0.3250 - val_accuracy: 0.8678 - val_loss: 0.3677
# Epoch 10/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 905us/step - accuracy: 0.8855 - loss: 0.3161 - val_accuracy: 0.8658 - val_loss: 0.3685

# %% [markdown]
# ## Momentum optimization

# %% [markdown]
# Imaginemos una bola de bolos rodando por una pendiente suave sobre una superficie lisa: empezará despacio, pero cogerá impulso rápidamente hasta que alcance la velocidad terminal (si hay algo de fricción o resistencia del aire). Esta es la idea central de la optimización del impulso, propuesta por Boris Polyak en 1964. Por el contrario, el descenso por pendiente regular dará pequeños pasos cuando la pendiente sea suave y grandes pasos cuando la pendiente sea pronunciada, pero nunca cogerá velocidad. Como resultado, el descenso de gradiente regular es generalmente mucho más lento para alcanzar el mínimo que la optimización de impulso.

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9)

# %%
history_momentum = build_and_train_model(optimizer)  # extra code
# Out:
# Epoch 1/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 996us/step - accuracy: 0.6709 - loss: 0.9996 - val_accuracy: 0.8140 - val_loss: 0.5112
# Epoch 2/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 916us/step - accuracy: 0.8301 - loss: 0.4859 - val_accuracy: 0.8320 - val_loss: 0.4520
# Epoch 3/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 944us/step - accuracy: 0.8479 - loss: 0.4327 - val_accuracy: 0.8460 - val_loss: 0.4182
# Epoch 4/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 987us/step - accuracy: 0.8601 - loss: 0.4006 - val_accuracy: 0.8516 - val_loss: 0.3998
# Epoch 5/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 947us/step - accuracy: 0.8668 - loss: 0.3778 - val_accuracy: 0.8556 - val_loss: 0.3853
# Epoch 6/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 966us/step - accuracy: 0.8730 - loss: 0.3608 - val_accuracy: 0.8590 - val_loss: 0.3774
# Epoch 7/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 898us/step - accuracy: 0.8771 - loss: 0.3471 - val_accuracy: 0.8634 - val_loss: 0.3714
# Epoch 8/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 893us/step - accuracy: 0.8807 - loss: 0.3356 - val_accuracy: 0.8648 - val_loss: 0.3665
# Epoch 9/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 893us/step - accuracy: 0.8840 - loss: 0.3253 - val_accuracy: 0.8660 - val_loss: 0.3628
# Epoch 10/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 892us/step - accuracy: 0.8874 - loss: 0.3163 - val_accuracy: 0.8682 - val_loss: 0.3581

# %% [markdown]
# ## Nesterov Accelerated Gradient

# %% [markdown]
# Una pequeña variante de la optimización del momento, propuesta por Yurii Nesterov en 1983, es casi siempre más rápida que la optimización del momento normal. El método del gradiente acelerado de Nesterov (NAG), también conocido como optimización del momento de Nesterov, mide el gradiente de la función de coste no en la posición local θ, sino ligeramente por delante en la dirección del momento, en θ + βm.

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001, momentum=0.9,
                                    nesterov=True)

# %%
history_nesterov = build_and_train_model(optimizer)
# Out:
# Epoch 1/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 982us/step - accuracy: 0.6698 - loss: 0.9808 - val_accuracy: 0.8276 - val_loss: 0.4918
# Epoch 2/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8330 - loss: 0.4789 - val_accuracy: 0.8446 - val_loss: 0.4429
# Epoch 3/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 991us/step - accuracy: 0.8485 - loss: 0.4275 - val_accuracy: 0.8526 - val_loss: 0.4133
# Epoch 4/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 935us/step - accuracy: 0.8573 - loss: 0.3982 - val_accuracy: 0.8562 - val_loss: 0.3983
# Epoch 5/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 938us/step - accuracy: 0.8655 - loss: 0.3767 - val_accuracy: 0.8604 - val_loss: 0.3845
# Epoch 6/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 946us/step - accuracy: 0.8714 - loss: 0.3603 - val_accuracy: 0.8594 - val_loss: 0.3786
# Epoch 7/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 981us/step - accuracy: 0.8748 - loss: 0.3470 - val_accuracy: 0.8638 - val_loss: 0.3696
# Epoch 8/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 939us/step - accuracy: 0.8797 - loss: 0.3343 - val_accuracy: 0.8652 - val_loss: 0.3674
# Epoch 9/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 943us/step - accuracy: 0.8829 - loss: 0.3240 - val_accuracy: 0.8656 - val_loss: 0.3638
# Epoch 10/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 924us/step - accuracy: 0.8856 - loss: 0.3145 - val_accuracy: 0.8672 - val_loss: 0.3607

# %% [markdown]
# ## AdaGrad

# %% [markdown]
# Consideremos de nuevo el problema del cuenco alargado: el descenso por gradiente empieza bajando rápidamente por la pendiente más pronunciada, que no apunta directamente hacia el óptimo global, y luego baja muy lentamente hasta el fondo del valle. Sería bueno que el algoritmo pudiera corregir su dirección antes para apuntar un poco más hacia el óptimo global. El algoritmo AdaGrad17 consigue esta corrección reduciendo la escala del vector gradiente a lo largo de las cotas más empinadas.

# %%
optimizer = tf.keras.optimizers.Adagrad(learning_rate=0.001)

# %%
history_adagrad = build_and_train_model(optimizer)
# Out:
# Epoch 1/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.5271 - loss: 1.3945 - val_accuracy: 0.7736 - val_loss: 0.6997
# Epoch 2/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 943us/step - accuracy: 0.7763 - loss: 0.6765 - val_accuracy: 0.8058 - val_loss: 0.5929
# Epoch 3/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 943us/step - accuracy: 0.8047 - loss: 0.5893 - val_accuracy: 0.8190 - val_loss: 0.5477
# Epoch 4/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 934us/step - accuracy: 0.8170 - loss: 0.5481 - val_accuracy: 0.8242 - val_loss: 0.5212
# Epoch 5/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 948us/step - accuracy: 0.8242 - loss: 0.5229 - val_accuracy: 0.8286 - val_loss: 0.5036
# Epoch 6/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 932us/step - accuracy: 0.8286 - loss: 0.5055 - val_accuracy: 0.8296 - val_loss: 0.4905
# Epoch 7/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 987us/step - accuracy: 0.8328 - loss: 0.4922 - val_accuracy: 0.8330 - val_loss: 0.4802
# Epoch 8/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 915us/step - accuracy: 0.8360 - loss: 0.4817 - val_accuracy: 0.8350 - val_loss: 0.4720
# Epoch 9/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 932us/step - accuracy: 0.8381 - loss: 0.4728 - val_accuracy: 0.8384 - val_loss: 0.4649
# Epoch 10/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 955us/step - accuracy: 0.8409 - loss: 0.4652 - val_accuracy: 0.8396 - val_loss: 0.4588

# %% [markdown]
# ## RMSProp

# %% [markdown]
# Como hemos visto, AdaGrad corre el riesgo de ralentizarse demasiado rápido y no converger nunca al óptimo global. El algoritmo RMSProp18 soluciona esto acumulando sólo los gradientes de las iteraciones más recientes, en lugar de todos los gradientes desde el principio del entrenamiento. Para ello, utiliza un decaimiento exponencial en el primer paso.

# %%
optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.001, rho=0.9)

# %%
history_rmsprop = build_and_train_model(optimizer)
# Out:
# Epoch 1/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.7606 - loss: 0.6603 - val_accuracy: 0.8330 - val_loss: 0.4409
# Epoch 2/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 971us/step - accuracy: 0.8543 - loss: 0.4001 - val_accuracy: 0.8528 - val_loss: 0.4066
# Epoch 3/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 976us/step - accuracy: 0.8698 - loss: 0.3685 - val_accuracy: 0.8572 - val_loss: 0.4097
# Epoch 4/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 986us/step - accuracy: 0.8761 - loss: 0.3510 - val_accuracy: 0.8562 - val_loss: 0.4600
# Epoch 5/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 978us/step - accuracy: 0.8802 - loss: 0.3418 - val_accuracy: 0.8508 - val_loss: 0.4988
# Epoch 6/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 999us/step - accuracy: 0.8823 - loss: 0.3375 - val_accuracy: 0.8362 - val_loss: 0.6057
# Epoch 7/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 965us/step - accuracy: 0.8826 - loss: 0.3418 - val_accuracy: 0.8590 - val_loss: 0.4464
# Epoch 8/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 966us/step - accuracy: 0.8852 - loss: 0.3378 - val_accuracy: 0.8554 - val_loss: 0.4890
# Epoch 9/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 983us/step - accuracy: 0.8835 - loss: 0.3385 - val_accuracy: 0.8668 - val_loss: 0.4901
# Epoch 10/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 958us/step - accuracy: 0.8875 - loss: 0.3343 - val_accuracy: 0.8462 - val_loss: 0.5885

# %% [markdown]
# ## Adam Optimization

# %% [markdown]
# Adam, que significa estimación adaptativa del momento, combina las ideas de la optimización del momento y RMSProp: al igual que la optimización del momento, realiza un seguimiento de una media exponencialmente decreciente de gradientes pasados; y al igual que RMSProp, realiza un seguimiento de una media exponencialmente decreciente de gradientes pasados al cuadrado. Estas son estimaciones de la media y la varianza (no centrada) de los gradientes. La media se suele llamar primer momento, mientras que la varianza se suele llamar segundo momento, de ahí el nombre del algoritmo.

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9,
                                     beta_2=0.999)

# %%
history_adam = build_and_train_model(optimizer)
# Out:
# Epoch 1/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7704 - loss: 0.6496 - val_accuracy: 0.8258 - val_loss: 0.4429
# Epoch 2/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8559 - loss: 0.3972 - val_accuracy: 0.8484 - val_loss: 0.3941
# Epoch 3/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8725 - loss: 0.3467 - val_accuracy: 0.8504 - val_loss: 0.3868
# Epoch 4/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8805 - loss: 0.3211 - val_accuracy: 0.8608 - val_loss: 0.3701
# Epoch 5/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8888 - loss: 0.2996 - val_accuracy: 0.8608 - val_loss: 0.3788
# Epoch 6/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8946 - loss: 0.2823 - val_accuracy: 0.8622 - val_loss: 0.3794
# Epoch 7/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8990 - loss: 0.2681 - val_accuracy: 0.8664 - val_loss: 0.3624
# Epoch 8/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9031 - loss: 0.2589 - val_accuracy: 0.8618 - val_loss: 0.3888
# Epoch 9/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9054 - loss: 0.2478 - val_accuracy: 0.8664 - val_loss: 0.3766
# Epoch 10/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9100 - loss: 0.2354 - val_accuracy: 0.8656 - val_loss: 0.4114

# %% [markdown]
# **Adamax Optimization**

# %% [markdown]
# Adam reduce las actualizaciones de parámetros por la norma ℓ2 de los gradientes de tiempo decaído (recordemos que la norma ℓ2 es la raíz cuadrada de la suma de cuadrados).

# %%
optimizer = tf.keras.optimizers.Adamax(learning_rate=0.001, beta_1=0.9,
                                       beta_2=0.999)

# %%
history_adamax = build_and_train_model(optimizer)
# Out:
# Epoch 1/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7595 - loss: 0.7084 - val_accuracy: 0.8358 - val_loss: 0.4356
# Epoch 2/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8543 - loss: 0.4150 - val_accuracy: 0.8512 - val_loss: 0.3949
# Epoch 3/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8665 - loss: 0.3699 - val_accuracy: 0.8614 - val_loss: 0.3663
# Epoch 4/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8770 - loss: 0.3411 - val_accuracy: 0.8640 - val_loss: 0.3571
# Epoch 5/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8822 - loss: 0.3197 - val_accuracy: 0.8688 - val_loss: 0.3475
# Epoch 6/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8895 - loss: 0.3032 - val_accuracy: 0.8702 - val_loss: 0.3418
# Epoch 7/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8943 - loss: 0.2894 - val_accuracy: 0.8718 - val_loss: 0.3394
# Epoch 8/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8983 - loss: 0.2776 - val_accuracy: 0.8718 - val_loss: 0.3394
# Epoch 9/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9019 - loss: 0.2671 - val_accuracy: 0.8744 - val_loss: 0.3368
# Epoch 10/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9060 - loss: 0.2575 - val_accuracy: 0.8788 - val_loss: 0.3342

# %% [markdown]
# **Nadam Optimization**

# %% [markdown]
# La optimización Nadam es la optimización Adam más el truco Nesterov, por lo que a menudo convergerá ligeramente más rápido que Adam. En su informe de presentación de esta técnica, el investigador Timothy Dozat compara muchos optimizadores diferentes en varias tareas y descubre que Nadam suele superar a Adam, pero a veces es superado por RMSProp.

# %%
optimizer = tf.keras.optimizers.Nadam(learning_rate=0.001, beta_1=0.9,
                                      beta_2=0.999)

# %%
history_nadam = build_and_train_model(optimizer)
# Out:
# Epoch 1/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7793 - loss: 0.6261 - val_accuracy: 0.8412 - val_loss: 0.4176
# Epoch 2/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8627 - loss: 0.3790 - val_accuracy: 0.8542 - val_loss: 0.3829
# Epoch 3/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8757 - loss: 0.3392 - val_accuracy: 0.8542 - val_loss: 0.3863
# Epoch 4/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.8856 - loss: 0.3124 - val_accuracy: 0.8566 - val_loss: 0.3764
# Epoch 5/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8934 - loss: 0.2916 - val_accuracy: 0.8668 - val_loss: 0.3702
# Epoch 6/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8959 - loss: 0.2801 - val_accuracy: 0.8720 - val_loss: 0.3472
# Epoch 7/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9032 - loss: 0.2621 - val_accuracy: 0.8748 - val_loss: 0.3531
# Epoch 8/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9056 - loss: 0.2558 - val_accuracy: 0.8712 - val_loss: 0.3857
# Epoch 9/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9111 - loss: 0.2442 - val_accuracy: 0.8724 - val_loss: 0.3687
# Epoch 10/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9146 - loss: 0.2320 - val_accuracy: 0.8724 - val_loss: 0.3756

# %% [markdown]
# **AdamW Optimization**

# %% [markdown]
# Es una variante de Adam que integra una técnica de regularización llamada decaimiento del peso. El decaimiento del peso reduce el tamaño de los pesos del modelo en cada iteración de entrenamiento multiplicándolos por un factor de decaimiento como 0,99. Esto puede recordarle a la regularización ℓ2, que también pretende mantener los pesos pequeños, y de hecho puede demostrarse matemáticamente que la regularización ℓ2 es equivalente al decaimiento del peso cuando se utiliza SGD. Sin embargo, cuando se utiliza Adam o sus variantes, la regularización ℓ2 y el decaimiento del peso no son equivalentes: en la práctica, la combinación de Adam con la regularización ℓ2 da lugar a modelos que a menudo no generalizan tan bien como los producidos por SGD. AdamW soluciona este problema combinando adecuadamente Adam con el decaimiento del peso.

# %% [markdown]
# Nota: Desde TF 1.12, `AdamW` ya no es experimental. Está disponible en `tf.keras.optimizers.AdamW` en lugar de `tf.keras.optimizers.experimental.AdamW`.

# %%
optimizer = tf.keras.optimizers.AdamW(weight_decay=1e-5, learning_rate=0.001,
                                      beta_1=0.9, beta_2=0.999)

# %%
history_adamw = build_and_train_model(optimizer)
# Out:
# Epoch 1/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.7690 - loss: 0.6519 - val_accuracy: 0.8466 - val_loss: 0.4000
# Epoch 2/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8587 - loss: 0.3888 - val_accuracy: 0.8378 - val_loss: 0.4065
# Epoch 3/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8727 - loss: 0.3460 - val_accuracy: 0.8268 - val_loss: 0.4230
# Epoch 4/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8830 - loss: 0.3189 - val_accuracy: 0.8568 - val_loss: 0.3789
# Epoch 5/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8891 - loss: 0.2975 - val_accuracy: 0.8556 - val_loss: 0.3876
# Epoch 6/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8949 - loss: 0.2824 - val_accuracy: 0.8534 - val_loss: 0.3941
# Epoch 7/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8990 - loss: 0.2683 - val_accuracy: 0.8686 - val_loss: 0.3665
# Epoch 8/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9032 - loss: 0.2559 - val_accuracy: 0.8744 - val_loss: 0.3567
# Epoch 9/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9075 - loss: 0.2454 - val_accuracy: 0.8748 - val_loss: 0.4131
# Epoch 10/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9114 - loss: 0.2376 - val_accuracy: 0.8680 - val_loss: 0.3939

# %%
# visualizar las curvas de aprendizaje de todos los optimizadores

for loss in ("loss", "val_loss"):
    plt.figure(figsize=(12, 8))
    opt_names = "SGD Momentum Nesterov AdaGrad RMSProp Adam Adamax Nadam AdamW"
    for history, opt_name in zip((history_sgd, history_momentum, history_nesterov,
                                  history_adagrad, history_rmsprop, history_adam,
                                  history_adamax, history_nadam, history_adamw),
                                 opt_names.split()):
        plt.plot(history.history[loss], label=f"{opt_name}", linewidth=3)

    plt.grid()
    plt.xlabel("Epochs")
    plt.ylabel({"loss": "Training loss", "val_loss": "Validation loss"}[loss])
    plt.legend(loc="upper left")
    plt.axis([0, 9, 0.1, 0.7])
    plt.show()

# %% [markdown]
# ## Learning Rate Scheduling

# %% [markdown]
# Encontrar una buena tasa de aprendizaje es muy importante. Si la ajusta demasiado alta, el entrenamiento puede divergir. Si la fijas demasiado baja, el entrenamiento convergerá eventualmente al óptimo, pero tardará mucho tiempo. Si lo estableces ligeramente demasiado alto, progresará muy rápido al principio, pero acabará bailando alrededor del óptimo y nunca se asentará realmente. Si dispone de un presupuesto de cálculo limitado, es posible que tenga que interrumpir el entrenamiento antes de que haya convergido correctamente, lo que dará lugar a una solución subóptima.

# %% [markdown]
# ### Programación de energía

# %% [markdown]
# ```python
# learning_rate = initial_learning_rate / (1 + step / decay_steps)**power
# ```
#
# Keras usa `power = 1`.

# %% [markdown]
# **Nota**: El argumento `decay` en los optimizadores está obsoleto. Los antiguos optimizadores que implementan el argumento `decay` siguen estando disponibles en `tf.keras.optimizers.legacy`, pero en su lugar deberías utilizar los programadores de `tf.keras.optimizers.schedules`.

# %%
lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
    initial_learning_rate=0.01,
    decay_steps=10_000,
    decay_rate=1.0,
    staircase=False
)
optimizer = tf.keras.optimizers.SGD(learning_rate=lr_schedule)

# %% [markdown]
# El programador `InverseTimeDecay` utiliza `learning_rate = initial_learning_rate / (1 + decay_rate * step / decay_steps)`. Si se establece `staircase=True`, se sustituye `step / decay_step` por `floor(step / decay_step)`.

# %%
history_power_scheduling = build_and_train_model(optimizer)
# Out:
# Epoch 1/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.6614 - loss: 0.9904 - val_accuracy: 0.8298 - val_loss: 0.4917
# Epoch 2/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8299 - loss: 0.4882 - val_accuracy: 0.8422 - val_loss: 0.4468
# Epoch 3/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 975us/step - accuracy: 0.8486 - loss: 0.4356 - val_accuracy: 0.8456 - val_loss: 0.4251
# Epoch 4/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 929us/step - accuracy: 0.8562 - loss: 0.4070 - val_accuracy: 0.8488 - val_loss: 0.4108
# Epoch 5/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 913us/step - accuracy: 0.8627 - loss: 0.3877 - val_accuracy: 0.8534 - val_loss: 0.4026
# Epoch 6/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8673 - loss: 0.3734 - val_accuracy: 0.8576 - val_loss: 0.3936
# Epoch 7/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8704 - loss: 0.3620 - val_accuracy: 0.8604 - val_loss: 0.3861
# Epoch 8/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8739 - loss: 0.3524 - val_accuracy: 0.8598 - val_loss: 0.3808
# Epoch 9/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8764 - loss: 0.3445 - val_accuracy: 0.8614 - val_loss: 0.3760
# Epoch 10/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8787 - loss: 0.3375 - val_accuracy: 0.8628 - val_loss: 0.3719

# %%
# esta celda traza la programación de potencia con staircase=True o False

initial_learning_rate = 0.01
decay_rate = 1.0
decay_steps = 10_000

steps = np.arange(100_000)
lrs = initial_learning_rate / (1 + decay_rate * steps / decay_steps)
lrs2 = initial_learning_rate / (1 + decay_rate * np.floor(steps / decay_steps))

plt.plot(steps, lrs,  "-", label="staircase=False")
plt.plot(steps, lrs2,  "-", label="staircase=True")
plt.axis([0, steps.max(), 0, 0.0105])
plt.xlabel("Step")
plt.ylabel("Learning Rate")
plt.title("Power Scheduling", fontsize=14)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Programación exponencial

# %% [markdown]
# ```python
# learning_rate = initial_learning_rate * decay_rate ** (step / decay_steps)
# ```

# %%
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.01,
    decay_steps=20_000,
    decay_rate=0.1,
    staircase=False
)
optimizer = tf.keras.optimizers.SGD(learning_rate=lr_schedule)

# %%
history_exponential_scheduling = build_and_train_model(optimizer)
# Out:
# Epoch 1/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step - accuracy: 0.6710 - loss: 0.9774 - val_accuracy: 0.8260 - val_loss: 0.4886
# Epoch 2/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8283 - loss: 0.4919 - val_accuracy: 0.8380 - val_loss: 0.4484
# Epoch 3/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8469 - loss: 0.4390 - val_accuracy: 0.8468 - val_loss: 0.4271
# Epoch 4/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8567 - loss: 0.4112 - val_accuracy: 0.8520 - val_loss: 0.4139
# Epoch 5/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8628 - loss: 0.3929 - val_accuracy: 0.8576 - val_loss: 0.4014
# Epoch 6/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8665 - loss: 0.3796 - val_accuracy: 0.8612 - val_loss: 0.3926
# Epoch 7/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8701 - loss: 0.3697 - val_accuracy: 0.8626 - val_loss: 0.3853
# Epoch 8/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8722 - loss: 0.3618 - val_accuracy: 0.8642 - val_loss: 0.3796
# Epoch 9/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 921us/step - accuracy: 0.8737 - loss: 0.3557 - val_accuracy: 0.8658 - val_loss: 0.3750
# Epoch 10/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 945us/step - accuracy: 0.8760 - loss: 0.3507 - val_accuracy: 0.8680 - val_loss: 0.3713

# %%
# esta celda traza una programación exponencial

initial_learning_rate = 0.01
decay_rate = 0.1
decay_steps = 20_000

steps = np.arange(100_000)
lrs = initial_learning_rate * decay_rate ** (steps / decay_steps)
lrs2 = initial_learning_rate * decay_rate ** np.floor(steps / decay_steps)

plt.plot(steps, lrs,  "-", label="staircase=False")
plt.plot(steps, lrs2,  "-", label="staircase=True")
plt.axis([0, steps.max(), 0, 0.0105])
plt.xlabel("Step")
plt.ylabel("Learning Rate")
plt.title("Exponential Scheduling", fontsize=14)
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Keras también proporciona una clase de callback `LearningRateScheduler` que te permite definir tu propia función de programación. Veamos cómo usarla para implementar el decaimiento exponencial. Tenga en cuenta que en este caso la tasa de aprendizaje sólo cambia en cada época, no en cada paso:

# %%
def exponential_decay_fn(epoch):
    return 0.01 * 0.1 ** (epoch / 20)

# %%
def exponential_decay(lr0, s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 ** (epoch / s)
    return exponential_decay_fn

exponential_decay_fn = exponential_decay(lr0=0.01, s=20)

# %%
# construir y compilar un modelo para Fashion MNIST

tf.random.set_seed(42)
model = build_model()
optimizer = tf.keras.optimizers.SGD(learning_rate=0.001)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])

# %%
n_epochs = 20

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)
history = model.fit(X_train, y_train, epochs=n_epochs,
                    validation_data=(X_valid, y_valid),
                    callbacks=[lr_scheduler])
# Out:
# Epoch 1/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 988us/step - accuracy: 0.6656 - loss: 0.9860 - val_accuracy: 0.8344 - val_loss: 0.4836 - learning_rate: 0.0100
# Epoch 2/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8331 - loss: 0.4886 - val_accuracy: 0.8374 - val_loss: 0.4457 - learning_rate: 0.0089
# Epoch 3/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8505 - loss: 0.4339 - val_accuracy: 0.8442 - val_loss: 0.4279 - learning_rate: 0.0079
# Epoch 4/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 936us/step - accuracy: 0.8598 - loss: 0.4042 - val_accuracy: 0.8472 - val_loss: 0.4174 - learning_rate: 0.0071
# Epoch 5/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8657 - loss: 0.3843 - val_accuracy: 0.8476 - val_loss: 0.4069 - learning_rate: 0.0063
# Epoch 6/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 946us/step - accuracy: 0.8696 - loss: 0.3694 - val_accuracy: 0.8512 - val_loss: 0.3981 - learning_rate: 0.0056
# Epoch 7/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 879us/step - accuracy: 0.8739 - loss: 0.3576 - val_accuracy: 0.8534 - val_loss: 0.3893 - learning_rate: 0.0050
# Epoch 8/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 886us/step - accuracy: 0.8768 - loss: 0.3480 - val_accuracy: 0.8558 - val_loss: 0.3824 - learning_rate: 0.0045
# Epoch 9/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 886us/step - accuracy: 0.8786 - loss: 0.3399 - val_accuracy: 0.8576 - val_loss: 0.3764 - learning_rate: 0.0040
# Epoch 10/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8813 - loss: 0.3330 - val_accuracy: 0.8616 - val_loss: 0.3713 - learning_rate: 0.0035
# Epoch 11/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8835 - loss: 0.3271 - val_accuracy: 0.8630 - val_loss: 0.3674 - learning_rate: 0.0032
# Epoch 12/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8850 - loss: 0.3219 - val_accuracy: 0.8646 - val_loss: 0.3645 - learning_rate: 0.0028
# Epoch 13/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 935us/step - accuracy: 0.8863 - loss: 0.3175 - val_accuracy: 0.8678 - val_loss: 0.3612 - learning_rate: 0.0025
# Epoch 14/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 943us/step - accuracy: 0.8874 - loss: 0.3137 - val_accuracy: 0.8680 - val_loss: 0.3587 - learning_rate: 0.0022
# Epoch 15/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 941us/step - accuracy: 0.8881 - loss: 0.3103 - val_accuracy: 0.8692 - val_loss: 0.3561 - learning_rate: 0.0020
# Epoch 16/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8893 - loss: 0.3073 - val_accuracy: 0.8694 - val_loss: 0.3539 - learning_rate: 0.0018
# Epoch 17/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 992us/step - accuracy: 0.8901 - loss: 0.3046 - val_accuracy: 0.8700 - val_loss: 0.3518 - learning_rate: 0.0016
# Epoch 18/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 954us/step - accuracy: 0.8913 - loss: 0.3022 - val_accuracy: 0.8698 - val_loss: 0.3498 - learning_rate: 0.0014
# Epoch 19/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 981us/step - accuracy: 0.8920 - loss: 0.3002 - val_accuracy: 0.8696 - val_loss: 0.3483 - learning_rate: 0.0013
# Epoch 20/20
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 894us/step - accuracy: 0.8928 - loss: 0.2984 - val_accuracy: 0.8706 - val_loss: 0.3469 - learning_rate: 0.0011

# %% [markdown]
# Alternativamente, la función de programación puede tomar el ritmo de aprendizaje actual como segundo argumento:

# %%
def exponential_decay_fn(epoch, lr):
    return lr * 0.1 ** (1 / 20)

# %% [markdown]
# ### Programación constante a trozos

# %%
lr_schedule = tf.keras.optimizers.schedules.PiecewiseConstantDecay(
    boundaries=[50_000, 80_000],
    values=[0.01, 0.005, 0.001]
)
optimizer = tf.keras.optimizers.SGD(learning_rate=lr_schedule)

# %%
history_piecewise_scheduling = build_and_train_model(optimizer)
# Out:
# Epoch 1/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1000us/step - accuracy: 0.6842 - loss: 0.9461 - val_accuracy: 0.8278 - val_loss: 0.4848
# Epoch 2/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 928us/step - accuracy: 0.8316 - loss: 0.4843 - val_accuracy: 0.8376 - val_loss: 0.4365
# Epoch 3/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 967us/step - accuracy: 0.8473 - loss: 0.4318 - val_accuracy: 0.8434 - val_loss: 0.4150
# Epoch 4/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 902us/step - accuracy: 0.8581 - loss: 0.4013 - val_accuracy: 0.8510 - val_loss: 0.3993
# Epoch 5/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 923us/step - accuracy: 0.8651 - loss: 0.3798 - val_accuracy: 0.8536 - val_loss: 0.3919
# Epoch 6/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 934us/step - accuracy: 0.8703 - loss: 0.3629 - val_accuracy: 0.8592 - val_loss: 0.3825
# Epoch 7/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 888us/step - accuracy: 0.8734 - loss: 0.3491 - val_accuracy: 0.8584 - val_loss: 0.3794
# Epoch 8/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 868us/step - accuracy: 0.8774 - loss: 0.3374 - val_accuracy: 0.8606 - val_loss: 0.3763
# Epoch 9/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 889us/step - accuracy: 0.8813 - loss: 0.3270 - val_accuracy: 0.8616 - val_loss: 0.3705
# Epoch 10/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 883us/step - accuracy: 0.8845 - loss: 0.3175 - val_accuracy: 0.8636 - val_loss: 0.3686

# %%
# esta celda traza una programación constante a trozos

boundaries = [50_000, 80_000]
values = [0.01, 0.005, 0.001]

steps = np.arange(100_000)

lrs = np.full(len(steps), values[0])
for boundary, value in zip(boundaries, values[1:]):
    lrs[boundary:] = value

plt.plot(steps, lrs, "-")
plt.axis([0, steps.max(), 0, 0.0105])
plt.xlabel("Step")
plt.ylabel("Learning Rate")
plt.title("Piecewise Constant Scheduling", fontsize=14)
plt.grid(True)
plt.show()

# %% [markdown]
# Al igual que hicimos con la programación exponencial, también podríamos implementar manualmente la programación constante a trozos:

# %%
def piecewise_constant_fn(epoch):
    if epoch < 5:
        return 0.01
    elif epoch < 15:
        return 0.005
    else:
        return 0.001

# %%
# esta celda demuestra una forma más general de definir
# programación constante a trozos.

def piecewise_constant(boundaries, values):
    boundaries = np.array([0] + boundaries)
    values = np.array(values)
    def piecewise_constant_fn(epoch):
        return values[(boundaries > epoch).argmax() - 1]
    return piecewise_constant_fn

piecewise_constant_fn = piecewise_constant([5, 15], [0.01, 0.005, 0.001])

# %%
# utilizar un tf.keras.callbacks.LearningRateScheduler como antes

n_epochs = 25

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(piecewise_constant_fn)

model = build_model()
optimizer = tf.keras.optimizers.Nadam(learning_rate=lr0)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])
history = model.fit(X_train, y_train, epochs=n_epochs,
                    validation_data=(X_valid, y_valid),
                    callbacks=[lr_scheduler])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 8
#       5 lr_scheduler = tf.keras.callbacks.LearningRateScheduler(piecewise_constant_fn)
#       7 model = build_model()
# ----> 8 optimizer = tf.keras.optimizers.Nadam(learning_rate=lr0)
#       9 model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
#      10               metrics=["accuracy"])
#      11 history = model.fit(X_train, y_train, epochs=n_epochs,
#      12                     validation_data=(X_valid, y_valid),
#      13                     callbacks=[lr_scheduler])
#
# NameError: name 'lr0' is not defined

# %% [markdown]
# Hemos visto `InverseTimeDecay`, `ExponentialDecay`, y `PiecewiseConstantDecay`. Algunos programadores más están disponibles en `tf.keras.optimizers.schedules`, aquí está la lista completa:

# %%
for name in sorted(dir(tf.keras.optimizers.schedules)):
    if name[0] == name[0].lower():
        continue
    scheduler_class = getattr(tf.keras.optimizers.schedules, name)
    print(f"• {name} - {scheduler_class.__doc__.splitlines()[0]}")
# Out:
# • CosineDecay - A `LearningRateSchedule` that uses a cosine decay with optional warmup.
# • CosineDecayRestarts - A `LearningRateSchedule` that uses a cosine decay schedule with restarts.
# • ExponentialDecay - A `LearningRateSchedule` that uses an exponential decay schedule.
# • InverseTimeDecay - A `LearningRateSchedule` that uses an inverse time decay schedule.
# • LearningRateSchedule - The learning rate schedule base class.
# • PiecewiseConstantDecay - A `LearningRateSchedule` that uses a piecewise constant decay schedule.
# • PolynomialDecay - A `LearningRateSchedule` that uses a polynomial decay schedule.

# %% [markdown]
# ### Programación del rendimiento

# %%
# construir y compilar el modelo

model = build_model()
optimizer = tf.keras.optimizers.SGD(learning_rate=lr0)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])

# %%
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=5)
history = model.fit(X_train, y_train, epochs=n_epochs,
                    validation_data=(X_valid, y_valid),
                    callbacks=[lr_scheduler])
# Out:
# Epoch 1/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6762 - loss: 0.9684 - val_accuracy: 0.8084 - val_loss: 0.5177 - learning_rate: 0.0100
# Epoch 2/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8268 - loss: 0.4924 - val_accuracy: 0.8198 - val_loss: 0.4769 - learning_rate: 0.0100
# Epoch 3/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8474 - loss: 0.4338 - val_accuracy: 0.8302 - val_loss: 0.4555 - learning_rate: 0.0100
# Epoch 4/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8567 - loss: 0.4009 - val_accuracy: 0.8408 - val_loss: 0.4363 - learning_rate: 0.0100
# Epoch 5/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8635 - loss: 0.3780 - val_accuracy: 0.8484 - val_loss: 0.4175 - learning_rate: 0.0100
# Epoch 6/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8704 - loss: 0.3606 - val_accuracy: 0.8496 - val_loss: 0.4023 - learning_rate: 0.0100
# Epoch 7/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8739 - loss: 0.3466 - val_accuracy: 0.8514 - val_loss: 0.3927 - learning_rate: 0.0100
# Epoch 8/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8767 - loss: 0.3345 - val_accuracy: 0.8564 - val_loss: 0.3844 - learning_rate: 0.0100
# Epoch 9/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8817 - loss: 0.3239 - val_accuracy: 0.8578 - val_loss: 0.3793 - learning_rate: 0.0100
# Epoch 10/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8842 - loss: 0.3148 - val_accuracy: 0.8620 - val_loss: 0.3727 - learning_rate: 0.0100
# Epoch 11/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8876 - loss: 0.3066 - val_accuracy: 0.8638 - val_loss: 0.3690 - learning_rate: 0.0100
# Epoch 12/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8904 - loss: 0.2989 - val_accuracy: 0.8652 - val_loss: 0.3634 - learning_rate: 0.0100
# Epoch 13/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8933 - loss: 0.2921 - val_accuracy: 0.8656 - val_loss: 0.3625 - learning_rate: 0.0100
# Epoch 14/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8955 - loss: 0.2856 - val_accuracy: 0.8668 - val_loss: 0.3615 - learning_rate: 0.0100
# Epoch 15/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8969 - loss: 0.2796 - val_accuracy: 0.8684 - val_loss: 0.3562 - learning_rate: 0.0100
# Epoch 16/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8998 - loss: 0.2738 - val_accuracy: 0.8684 - val_loss: 0.3550 - learning_rate: 0.0100
# Epoch 17/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9023 - loss: 0.2680 - val_accuracy: 0.8698 - val_loss: 0.3544 - learning_rate: 0.0100
# Epoch 18/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9046 - loss: 0.2631 - val_accuracy: 0.8706 - val_loss: 0.3545 - learning_rate: 0.0100
# Epoch 19/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9060 - loss: 0.2578 - val_accuracy: 0.8726 - val_loss: 0.3507 - learning_rate: 0.0100
# Epoch 20/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9078 - loss: 0.2528 - val_accuracy: 0.8740 - val_loss: 0.3494 - learning_rate: 0.0100
# Epoch 21/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9098 - loss: 0.2479 - val_accuracy: 0.8728 - val_loss: 0.3494 - learning_rate: 0.0100
# Epoch 22/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9113 - loss: 0.2436 - val_accuracy: 0.8734 - val_loss: 0.3492 - learning_rate: 0.0100
# Epoch 23/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9135 - loss: 0.2393 - val_accuracy: 0.8746 - val_loss: 0.3494 - learning_rate: 0.0100
# Epoch 24/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9144 - loss: 0.2352 - val_accuracy: 0.8738 - val_loss: 0.3473 - learning_rate: 0.0100
# Epoch 25/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9168 - loss: 0.2310 - val_accuracy: 0.8756 - val_loss: 0.3471 - learning_rate: 0.0100

# %%
# esta celda traza la programación del rendimiento

plt.plot(history.epoch, history.history["learning_rate"], "bo-")
plt.xlabel("Epoch")
plt.ylabel("Learning Rate", color='b')
plt.tick_params('y', colors='b')
plt.gca().set_xlim(0, n_epochs - 1)
plt.grid(True)

ax2 = plt.gca().twinx()
ax2.plot(history.epoch, history.history["val_loss"], "r^-")
ax2.set_ylabel('Validation Loss', color='r')
ax2.tick_params('y', colors='r')

plt.title("Reduce LR on Plateau", fontsize=14)
plt.show()

# %% [markdown]
# ### 1Cycle scheduling

# %% [markdown]
# El callback personalizado `ExponentialLearningRate` actualiza la tasa de aprendizaje durante el entrenamiento, al final de cada lote. La multiplica por un "factor" constante. También guarda la tasa de aprendizaje y la pérdida en cada lote. Dado que `logs["loss"]` es en realidad la pérdida media desde el inicio de la época, y queremos guardar la pérdida del lote en su lugar, debemos calcular la media por el número de lotes desde el inicio de la época para obtener la pérdida total hasta el momento, luego restamos la pérdida total en el lote anterior para obtener la pérdida del lote actual.

# %%
K = tf.keras.backend

class ExponentialLearningRate(tf.keras.callbacks.Callback):
    def __init__(self, factor):
        self.factor = factor
        self.rates = []
        self.losses = []

    def on_epoch_begin(self, epoch, logs=None):
        self.sum_of_epoch_losses = 0

    def on_batch_end(self, batch, logs=None):
        mean_epoch_loss = logs["loss"]  
        new_sum_of_epoch_losses = mean_epoch_loss * (batch + 1)
        batch_loss = new_sum_of_epoch_losses - self.sum_of_epoch_losses
        self.sum_of_epoch_losses = new_sum_of_epoch_losses
        self.rates.append(K.get_value(self.model.optimizer.learning_rate))
        self.losses.append(batch_loss)
        K.set_value(self.model.optimizer.learning_rate,
                    self.model.optimizer.learning_rate * self.factor)

# %% [markdown]
# La función `find_learning_rate()` entrena el modelo utilizando la llamada de retorno `ExponentialLearningRate`, y devuelve las tasas de aprendizaje y las pérdidas por lotes correspondientes. Al final, restaura el modelo y su optimizador a su estado inicial.

# %%
def find_learning_rate(model, X, y, epochs=1, batch_size=32, min_rate=1e-4,
                       max_rate=1):
    init_weights = model.get_weights()
    iterations = math.ceil(len(X) / batch_size) * epochs
    factor = (max_rate / min_rate) ** (1 / iterations)
    init_lr = K.get_value(model.optimizer.learning_rate)
    K.set_value(model.optimizer.learning_rate, min_rate)
    exp_lr = ExponentialLearningRate(factor)
    history = model.fit(X, y, epochs=epochs, batch_size=batch_size,
                        callbacks=[exp_lr])
    K.set_value(model.optimizer.learning_rate, init_lr)
    model.set_weights(init_weights)
    return exp_lr.rates, exp_lr.losses

# %% [markdown]
# La función `plot_lr_vs_loss()` representa las tasas de aprendizaje frente a las pérdidas. La tasa de aprendizaje óptima para usar como tasa de aprendizaje máxima en 1cycle está cerca de la parte inferior de la curva.

# %%
def plot_lr_vs_loss(rates, losses):
    plt.plot(rates, losses, "b")
    plt.gca().set_xscale('log')
    max_loss = losses[0] + min(losses)
    plt.hlines(min(losses), min(rates), max(rates), color="k")
    plt.axis([min(rates), max(rates), 0, max_loss])
    plt.xlabel("Learning rate")
    plt.ylabel("Loss")
    plt.grid()

# %% [markdown]
# Construyamos un sencillo modelo Fashion MNIST y compilémoslo:

# %%
model = build_model()
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
              metrics=["accuracy"])
# Out:
# c:\Users\jamr1\Desktop\Clases_DS\Bootcamp_DS\.venv\Lib\site-packages\keras\src\layers\reshaping\flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# El callback personalizado `OneCycleScheduler` actualiza la tasa de aprendizaje al principio de cada lote. Aplica la lógica descrita en el libro: aumenta la tasa de aprendizaje linealmente durante aproximadamente la mitad del entrenamiento, luego la reduce linealmente de vuelta a la tasa de aprendizaje inicial y, por último, la reduce linealmente hasta cerca de cero para la última parte del entrenamiento.

# %%
class OneCycleScheduler(tf.keras.callbacks.Callback):
    def __init__(self, iterations, max_lr=1e-3, start_lr=None,
                 last_iterations=None, last_lr=None):
        self.iterations = iterations
        self.max_lr = max_lr
        self.start_lr = start_lr or max_lr / 10
        self.last_iterations = last_iterations or iterations // 10 + 1
        self.half_iteration = (iterations - self.last_iterations) // 2
        self.last_lr = last_lr or self.start_lr / 1000
        self.iteration = 0

    def _interpolate(self, iter1, iter2, lr1, lr2):
        return (lr2 - lr1) * (self.iteration - iter1) / (iter2 - iter1) + lr1

    def on_batch_begin(self, batch, logs):
        if self.iteration < self.half_iteration:
            lr = self._interpolate(0, self.half_iteration, self.start_lr,
                                   self.max_lr)
        elif self.iteration < 2 * self.half_iteration:
            lr = self._interpolate(self.half_iteration, 2 * self.half_iteration,
                                   self.max_lr, self.start_lr)
        else:
            lr = self._interpolate(2 * self.half_iteration, self.iterations,
                                   self.start_lr, self.last_lr)
        self.iteration += 1
        K.set_value(self.model.optimizer.learning_rate, lr)

# %% [markdown]
# # Evitar el sobreajuste mediante la regularización

# %% [markdown]
# ## $\ell_1$ and $\ell_2$ regularization

# %%
layer = tf.keras.layers.Dense(100, activation="relu",
                              kernel_initializer="he_normal",
                              kernel_regularizer=tf.keras.regularizers.l2(0.01))

# %% [markdown]
# O utilice `l1(0,1)` para la regularización ℓ<sub>1</sub> con un factor de 0,1, o `l1_l2(0,1, 0,01)` tanto para la regularización ℓ<sub>1</sub> como para la regularización ℓ<sub>2</sub>, con factores 0,1 y 0,01 respectivamente.

# %%
tf.random.set_seed(42)

# %%
from functools import partial

RegularizedDense = partial(tf.keras.layers.Dense,
                           activation="relu",
                           kernel_initializer="he_normal",
                           kernel_regularizer=tf.keras.regularizers.l2(0.01))

model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    RegularizedDense(100),
    RegularizedDense(100),
    RegularizedDense(10, activation="softmax")
])

# %%
# compilar y entrenar el modelo
optimizer = tf.keras.optimizers.SGD(learning_rate=0.02)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])
history = model.fit(X_train, y_train, epochs=2,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/2
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7056 - loss: 4.1317 - val_accuracy: 0.8216 - val_loss: 1.8755
# Epoch 2/2
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8114 - loss: 1.6349 - val_accuracy: 0.8234 - val_loss: 1.1197

# %% [markdown]
# ## Dropout

# %% [markdown]
# Dropout es una de las técnicas de regularización más populares para redes neuronales profundas. Se propuso en un artículo de Geoffrey Hinton et al. en 2012 y se detalló en un artículo de 2014 de Nitish Srivastava et al., y ha demostrado ser muy eficaz: muchas redes neuronales de última generación utilizan dropout, ya que les proporciona un aumento de precisión del 1%-2%. Puede que no parezca mucho, pero cuando un modelo ya tiene una precisión del 95 %, conseguir un aumento de la precisión del 2 % significa reducir la tasa de error en casi un 40 % (pasar de un 5 % de error a aproximadamente un 3 %).

# %%
tf.random.set_seed(42)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(100, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dropout(rate=0.2),
    tf.keras.layers.Dense(10, activation="softmax")
])

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])
history = model.fit(X_train, y_train, epochs=10,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6761 - loss: 0.8780 - val_accuracy: 0.8236 - val_loss: 0.4630
# Epoch 2/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8058 - loss: 0.5266 - val_accuracy: 0.8488 - val_loss: 0.4084
# Epoch 3/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8258 - loss: 0.4827 - val_accuracy: 0.8528 - val_loss: 0.3949
# Epoch 4/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8341 - loss: 0.4587 - val_accuracy: 0.8582 - val_loss: 0.3856
# Epoch 5/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8388 - loss: 0.4385 - val_accuracy: 0.8558 - val_loss: 0.3818
# Epoch 6/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8444 - loss: 0.4287 - val_accuracy: 0.8558 - val_loss: 0.3750
# Epoch 7/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8453 - loss: 0.4180 - val_accuracy: 0.8638 - val_loss: 0.3580
# Epoch 8/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8480 - loss: 0.4116 - val_accuracy: 0.8670 - val_loss: 0.3568
# Epoch 9/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8526 - loss: 0.3979 - val_accuracy: 0.8678 - val_loss: 0.3487
# Epoch 10/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8548 - loss: 0.3941 - val_accuracy: 0.8726 - val_loss: 0.3394

# %% [markdown]
# Parece que la precisión del entrenamiento es menor que la de la validación, pero esto se debe a que el abandono sólo está activo durante el entrenamiento. Si evaluamos el modelo en el conjunto de entrenamiento después del entrenamiento (es decir, con el abandono desactivado), obtendremos la precisión de entrenamiento "real", que es ligeramente superior a la precisión de validación y a la precisión de prueba:

# %%
model.evaluate(X_train, y_train)
# Out:
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.8883 - loss: 0.3027
# [0.3049008548259735, 0.8880545496940613]

# %%
model.evaluate(X_test, y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8659 - loss: 0.3580
# [0.3620859384536743, 0.8632000088691711]

# %% [markdown]
# **Nota**: asegúrate de usar `AlphaDropout` en lugar de `Dropout` si quieres construir una red neuronal autonormalizadora usando SELU.

# %% [markdown]
# ## MC Dropout

# %% [markdown]
# En 2016, un artículo28 de Yarin Gal y Zoubin Ghahramani añadió algunas buenas razones más para utilizar el abandono:
#
# - En primer lugar, el artículo estableció una profunda conexión entre las redes de abandono (es decir, las redes neuronales que contienen capas de abandono) y la inferencia bayesiana aproximada,29 dando a la deserción una sólida justificación matemática.
#
# - En segundo lugar, los autores introdujeron una potente técnica denominada MC dropout, que
# puede aumentar el rendimiento de cualquier modelo de abandono entrenado sin tener que volver a entrenarlo o incluso modificarlo en absoluto. También proporciona una medida mucho mejor de la incertidumbre del modelo, y puede implementarse en unas pocas líneas de código.
#
# Si todo esto le suena a "un truco raro", eche un vistazo al siguiente código. Es la implementación completa de MC dropout, potenciando el modelo dropout que entrenamos anteriormente sin reentrenarlo:

# %%
tf.random.set_seed(42)

# %%
y_probas = np.stack([model(X_test, training=True)
                     for sample in range(100)])
y_proba = y_probas.mean(axis=0)

# %%
model.predict(X_test[:1]).round(3)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# array([[0.   , 0.   , 0.   , 0.   , 0.   , 0.023, 0.   , 0.055, 0.   ,
#         0.922]], dtype=float32)

# %%
y_proba[0].round(3)
# Out:
# array([0.   , 0.   , 0.   , 0.   , 0.   , 0.087, 0.   , 0.072, 0.   ,
#        0.841], dtype=float32)

# %%
y_std = y_probas.std(axis=0)
y_std[0].round(3)
# Out:
# array([0.   , 0.   , 0.   , 0.   , 0.   , 0.146, 0.   , 0.095, 0.   ,
#        0.159], dtype=float32)

# %%
y_pred = y_proba.argmax(axis=1)
accuracy = (y_pred == y_test).sum() / len(y_test)
accuracy
# Out:
# 0.8657

# %%
class MCDropout(tf.keras.layers.Dropout):
    def call(self, inputs, training=None):
        return super().call(inputs, training=True)

# %%
# muestra cómo convertir Dropout en MCDropout en un modelo secuencial
Dropout = tf.keras.layers.Dropout
mc_model = tf.keras.Sequential([
    MCDropout(layer.rate) if isinstance(layer, Dropout) else layer
    for layer in model.layers
])
mc_model.set_weights(model.get_weights())

# %%
mc_model.summary()
# Out:
# Model: "sequential_26"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_23 (Flatten)            │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mc_dropout (MCDropout)          │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_93 (Dense)                │ (None, 100)            │        78,500 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mc_dropout_1 (MCDropout)        │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_94 (Dense)                │ (None, 100)            │        10,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ mc_dropout_2 (MCDropout)        │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_95 (Dense)                │ (None, 10)             │         1,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 89,610 (350.04 KB)
#  Trainable params: 89,610 (350.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Ahora podemos utilizar el modelo con MC Dropout:

# %%
# muestra que el modelo funciona sin reentrenamiento
tf.random.set_seed(42)
np.mean([mc_model.predict(X_test[:1])
         for sample in range(100)], axis=0).round(2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# array([[0.  , 0.  , 0.  , 0.  , 0.  , 0.07, 0.  , 0.07, 0.  , 0.86]],
#       dtype=float32)

# %% [markdown]
# ## Max norm

# %% [markdown]
# Otra técnica popular de regularización para redes neuronales es la llamada regularización max-norma: para cada neurona, restringe los pesos w de las conexiones entrantes de tal forma que $∥ w ∥_2 ≤ r$, donde r es el hiperparámetro max-norma y $∥ - ∥_2$ es la norma ℓ2.

# %%
dense = tf.keras.layers.Dense(
    100, activation="relu", kernel_initializer="he_normal",
    kernel_constraint=tf.keras.constraints.max_norm(1.))

# %%
# muestra cómo aplicar la norma máxima a cada capa oculta de un modelo

MaxNormDense = partial(tf.keras.layers.Dense,
                       activation="relu", kernel_initializer="he_normal",
                       kernel_constraint=tf.keras.constraints.max_norm(1.))

tf.random.set_seed(42)
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=[28, 28]),
    MaxNormDense(100),
    MaxNormDense(100),
    tf.keras.layers.Dense(10, activation="softmax")
])
optimizer = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])
history = model.fit(X_train, y_train, epochs=10,
                    validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7409 - loss: 0.7220 - val_accuracy: 0.8360 - val_loss: 0.4295
# Epoch 2/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8439 - loss: 0.4261 - val_accuracy: 0.8414 - val_loss: 0.4123
# Epoch 3/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8581 - loss: 0.3875 - val_accuracy: 0.8404 - val_loss: 0.4061
# Epoch 4/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8644 - loss: 0.3666 - val_accuracy: 0.8434 - val_loss: 0.4046
# Epoch 5/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8705 - loss: 0.3504 - val_accuracy: 0.8498 - val_loss: 0.3891
# Epoch 6/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8707 - loss: 0.3435 - val_accuracy: 0.8442 - val_loss: 0.3965
# Epoch 7/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8749 - loss: 0.3329 - val_accuracy: 0.8404 - val_loss: 0.4140
# Epoch 8/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8772 - loss: 0.3297 - val_accuracy: 0.8484 - val_loss: 0.3909
# Epoch 9/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8804 - loss: 0.3222 - val_accuracy: 0.8482 - val_loss: 0.3861
# Epoch 10/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8801 - loss: 0.3167 - val_accuracy: 0.8550 - val_loss: 0.3830
