# %% [markdown]
# # Ejercicio Scraping
#
# Descargar letras de canciones
#
# Utilizando beautiful soup descargar todas las canciones de [Lasso](https://es.wikipedia.org/wiki/Lasso_(cantante)) que hay en [letras.com](https://www.letras.com/lasso/)

# %%
from bs4 import BeautifulSoup
import requests
import os

letras_url = "https://www.letras.com"

html_obtenido = requests.get(letras_url)
soup = BeautifulSoup(html_obtenido.text, "html.data-theme")


def descargar_letras(artista):

    return
        
artista = "lasso"
descargar_letras(artista)

# %%
from bs4 import BeautifulSoup
import requests
import os

letras_url = "https://www.letras.com"

html_obtenido = requests.get(letras_url)
soup = BeautifulSoup(html_obtenido.text, "html.parser")
soup
# Out:
# <!DOCTYPE HTML>
#  <html data-platform="desktop" data-theme="light" dir="ltr" lang="es"> <head prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#"> <title>LETRAS.COM - Letras de canciones</title> <meta content="Descubre letras de canciones, traducciones, escucha música, playlists, mira videos subtitulados en el sitio web de letras más grande de Latinoamérica." name="description"/> <meta content="letras de canciones, letras, canciones, letra de canción, letra, letras de canción" name="keywords"/> <meta charset="utf-8"/> <meta content="app-id=com.studiosol.player.letras" name="google-play-app"/> <meta content="214701744179" property="fb:pages"> <meta content="357922461263649" property="fb:app_id"/> <meta content="telephone=no" name="format-detection"/> <meta content="#c2c800" name="theme-color"/> <meta content="async" name="include_mode"> <meta content="app-id=773347891" name="apple-itunes-app"/> <meta content="width=device-width, initial-scale=1.0" name="viewport"/> <link href="https://www.letras.com/" rel="canonical"/> <link href="https://www.letras.com/" hreflang="es" rel="alternate"/> <link href="https://www.letras.mus.br/" hreflang="pt" rel="alternate"/> <script>document.documentElement.setAttribute("data-theme",document.cookie.match(new RegExp("theme=dark"))?"dark":document.cookie.match(new RegExp("theme=light"))?"light":window.matchMedia("(prefers-color-scheme: dark)").matches?"dark":"light");document.querySelector('meta[name="theme-color"]').setAttribute("content",document.documentElement.getAttribute("data-theme")==="dark"?"#0f0f0f":/(meaning|lyrics)/.test(window.origin)?"#fff":"#c2c800")</script> <link href="android-app://com.studiosol.player.letras/http/www.letras.com/" rel="alternate"/> <script type="application/ld+json">{"@context":"http://schema.org/","@type":"WebSite","name":"Letras.com","url":"https://www.letras.com/"}</script><script type="application/ld+json">{"@context":"http://schema.org/","@type":"BreadcrumbList","itemListElement":[{"@context":"http://schema.org/","@id":"https://www.letras.com/","@type":"ListItem","item":{"@id":"https://www.letras.com/","name":"Inicio","url":"https://www.letras.com/"},"position":0}],"itemListOrder":"Ascending","numberOfItems":1}</script> <meta content="https://akamai.sscdn.co/letras/desktop/static/img/og_letras_facebook.vc113c9d1.png" property="og:image"> <meta content="LETRAS.COM - Letras de canciones" property="og:title"> <meta content="https://www.letras.com/" property="og:url"> <meta content="website" property="og:type"/> <meta content="Letras.com" property="og:site_name"/> <link crossorigin="" href="https://akamai.sscdn.co" rel="preconnect"/> <link href="https://www.googletagmanager.com" rel="preconnect"/> <link href="https://solr.sscdn.co" rel="dns-prefetch"/> <link href="https://tpc.googlesyndication.com" rel="dns-prefetch"/> <link href="https://c.amazon-adsystem.com" rel="dns-prefetch"/> <link href="https://securepubads.g.doubleclick.net" rel="dns-prefetch"/> <link href="https://pagead2.googlesyndication.com" rel="dns-prefetch"/> <link href="https://prg.smartadserver.com" rel="dns-prefetch"/> <link href="https://fastlane.rubiconproject.com" rel="dns-prefetch"/> <link href="https://htlb.casalemedia.com/" rel="dns-prefetch"/> <link href="https://s.seedtag.com/" rel="dns-prefetch"/> <link href="http://a9.com/-/spec/opensearch/1.1/" rel="profile"/> <link href="//akamai.sscdn.co/letras/desktop/static/img/favicon.vb03794eb.ico" rel="icon" type="image/x-icon"> <link href="//akamai.sscdn.co/letras/mobile/static/img/apple-touch-icon.v838068f9.png" rel="apple-touch-icon"/> <link href="//akamai.sscdn.co/letras/mobile/static/img/apple-touch-icon.v838068f9.png" rel="apple-touch-icon" sizes="72x72"/> <link href="//akamai.sscdn.co/letras/mobile/static/img/apple-touch-icon.v838068f9.png" rel="apple-touch-icon" sizes="114x114"/> <link href="//akamai.sscdn.co/letras/mobile/static/img/apple-touch-icon.v838068f9.png" rel="apple-touch-icon" sizes="144x144"/> <link as="font" crossorigin="" href="https: ...
# var prebidAdUnits = [{"code":"pub_1_ad","mediaTypes":{"banner":{"sizes":[[1055,90],[970,90],[728,90]]}},"bids":[{"id":"appnexus-13921695","bidder":"appnexus","params":{"allow_smaller_sizes":true,"placement_id":"13921695"}},{"id":"rubicon-14458-101116-1046442","bidder":"rubicon","params":{"accountId":"14458","siteId":"101116","zoneId":"1046442"}},{"id":"smartadserver-69274","bidder":"smartadserver","params":{"domain":"https://prg.smartadserver.com","formatId":"69274","pageId":887594,"siteId":202484}},{"id":"ix-376638","bidder":"ix","labelAny":["AllowedIX"],"params":{"siteId":"376638"}},{"id":"eplanning","bidder":"eplanning","params":{"ci":"58f00"}},{"id":"pubmatic-165437-6246311","bidder":"pubmatic","params":{"adSlot":"6246311","publisherId":"165437"}}]},{"code":"pub_4_ad","mediaTypes":{"banner":{"sizes":[[728,90],[970,90],[1055,90]]}},"bids":[{"id":"appnexus-13893921","bidder":"appnexus","params":{"allow_smaller_sizes":true,"placement_id":"13893921"}},{"id":"rubicon-14458-101116-1046416","bidder":"rubicon","params":{"accountId":"14458","siteId":"101116","zoneId":"1046416"}},{"id":"smartadserver-69265","bidder":"smartadserver","params":{"domain":"https://prg.smartadserver.com","formatId":"69265","pageId":887594,"siteId":202484}},{"id":"smartadserver-69266","bidder":"smartadserver","params":{"domain":"https://prg.smartadserver.com","formatId":"69266","pageId":887594,"siteId":202484}},{"id":"ix-376641","bidder":"ix","labelAny":["AllowedIX"],"params":{"siteId":"376641"}},{"id":"eplanning","bidder":"eplanning","params":{"ci":"58f00"}},{"id":"pubmatic-165437-6246317","bidder":"pubmatic","params":{"adSlot":"6246317","publisherId":"165437"}}]},{"code":"pub_9_ad","mediaTypes":{"banner":{"sizes":[[728,90],[970,90],[970,250],[1055,90],[1055,250]]}},"bids":[{"id":"appnexus-13893937","bidder":"appnexus","params":{"allow_smaller_sizes":true,"placement_id":"13893937"}},{"id":"rubicon-14458-101116-1046438","bidder":"rubicon","params":{"accountId":"14458","siteId":"101116","zoneId":"1046438"}},{"id":"smartadserver-69268","bidder":"smartadserver","params":{"domain":"https://prg.smartadserver.com","formatId":"69268","pageId":887594,"siteId":202484}},{"id":"ix-376647","bidder":"ix","labelAny":["AllowedIX"],"params":{"siteId":"376647"}},{"id":"eplanning","bidder":"eplanning","params":{"ci":"58f00"}},{"id":"pubmatic-165437-6246331","bidder":"pubmatic","params":{"adSlot":"6246331","publisherId":"165437"}}]},{"code":"pub_25_ad","mediaTypes":{"banner":{"sizes":[[728,90],[970,90],[1055,90]]}},"bids":[{"id":"appnexus-17605983","bidder":"appnexus","params":{"allow_smaller_sizes":true,"placement_id":"17605983"}},{"id":"rubicon-14458-101116-1482254","bidder":"rubicon","params":{"accountId":"14458","siteId":"101116","zoneId":"1482254"}},{"id":"smartadserver-86054","bidder":"smartadserver","params":{"domain":"https://prg.smartadserver.com","formatId":"86054","pageId":887594,"siteId":202484}},{"id":"ix-427070","bidder":"ix","labelAny":["AllowedIX"],"params":{"siteId":"427070"}},{"id":"eplanning","bidder":"eplanning","params":{"ci":"58f00"}},{"id":"seedtag-29300534","bidder":"seedtag","params":{"adUnitId":"29300534","placement":"inBanner","publisherId":"7548-2597-01"}},{"id":"pubmatic-165437-6246309","bidder":"pubmatic","params":{"adSlot":"6246309","publisherId":"165437"}}]}];var prebidAdUnitsRefresh = [{"code":"pub_1_ad_refresh","mediaTypes":{"banner":{"sizes":[[1055,90],[970,90],[728,90]]}},"bids":[{"id":"appnexus-11451397","bidder":"appnexus","params":{"allow_smaller_sizes":true,"placement_id":"11451397"}},{"id":"rubicon-14458-101116-628798","bidder":"rubicon","params":{"accountId":"14458","siteId":"101116","zoneId":"628798"}},{"id":"smartadserver-62179","bidder":"smartadserver","params":{"domain":"https://prg.smartadserver.com","formatId":"62179","pageId":887594,"siteId":202484}},{"id":"ix-376623","bidder":"ix","labelAny":["AllowedIX"],"params":{"siteId":"376623"}},{"id":"eplanning","bidder":"eplanning","params":{"ci":"58f00"}},{"id":"pubmatic-165437-62463 ...
# window.adsqueue.push(()=>{window.adshb.init();});</script> <link href="https://www.letras.com/opensearchdescription.xml" rel="search" title="Búsqueda de letras" type="application/opensearchdescription+xml">
# <link href="/destaques.rss" rel="alternate" title="RSS Feed - Destacados - Letras.com" type="application/rss+xml">
# <link href="/destaques.atom" rel="alternate" title="Atom Feed - Destacados - Letras.com" type="application/atom+xml">
# <link href="/playlists.rss" rel="alternate" title="RSS Feed - Playlists - Letras.com" type="application/rss+xml">
# <link href="/playlists.atom" rel="alternate" title="Atom Feed - Playlists - Letras.com" type="application/atom+xml">
# <link href="/blog.rss" rel="alternate" title="RSS Feed - Blog - Letras.com" type="application/rss+xml"> <link href="/manifest.json" rel="manifest"/> <script>if(!("Promise"in window)){document.write('<script src="//akamai.sscdn.co/letras/common/static/js/promise.vd6adfb0c.js"><\/script>');}</script> </link></link></link></link></link></link></link></link></link></link></meta></meta></meta></meta></meta></head> <body class="es-es index" data-locale="es-es" id="body"> <script type="text/javascript">try{const matches=[...document.cookie.matchAll(/(lasub|lpsub)=([^;][A-Za-z0-9]{2,5})/g)];if(matches.length>0){document.body.classList.add("hasSubscription");for(const match of matches){if(match[1]=="lasub"){document.body.classList.add("hasSubscriptionAcademy");}if(match[1]=="lpsub"){document.body.classList.add("hasSubscriptionPremium");}}}}catch(e){}</script> <div class="wrapper"> <header class="header"> <div class="header-topBar"> <div class="gridContainer --noMarginBottom"> <div class="u-flex"> <button class="header-menuButton">menu</button> <div class="header-logoContainer"> <a class="header-logo" href="/"> <h1>LETRAS.COM - Letras de canciones</h1> </a> </div> </div> <form class="header-search suggest"> <label class="header-search-label"> <input aria-label="¿Qué quieres escuchar ahora?" autocomplete="off" class="header-search-input font --base --strong --size16" id="main_suggest" placeholder="¿Qué quieres escuchar ahora?"/> </label> <button class="header-search-submit" title="buscar">buscar</button> <div class="suggest-drop modal"> <ul class="suggest-list --mainSearch"></ul> <div class="suggest-all"></div> </div> </form> <div class="header-linksToLoggedUsers"> <span id="js-user-send" style="display: none"> <a class="font --base --strong --size16" data-ct-action="Nav Enviar Letra" data-ct-label="Barra (topo)" href="/contribuicoes/" rel="nofollow"> <strong>Enviar letra</strong> </a> </span> <span id="js-user-menu"></span> </div> </div> </div> <div class="header-menus"> <div class="gridContainer --noMarginBottom"> <div class="menu modal" id="js-main-menu-modal"> <div class="rail"></div> <div class="menu-tabs"> <ul> <li><a class="is-active" data-tab="menu-songs" href="/mais-acessadas/" id="js-music-tab">Canciones</a></li> <li><a data-tab="menu-artists" href="/mais-acessadas/">Artistas</a></li> <li><a data-tab="menu-musicalStyles" href="/estilos/">Géneros musicales</a></li> <li><a data-tab="menu-playlists" href="/playlists.html">Playlists</a></li> <li><a data-tab="menu-spotify" href="#">Spotify</a></li> <li><a data-tab="menu-dictionary" href="/academy/dicionario/">Práctica de pronunciación</a></li> <li><a data-tab="menu-blog" href="/blog/">Blog</a></li> <li><a data-tab="menu-apps" href="#">Aplicaciones</a></li> </ul> <a data-ct-action="Nav Enviar Letra" data-ct-label="Menu (topo)" href="/contribuicoes/" rel="nofollow">Enviar letra</a> </div> <div class="menu-content menu-songs is-active" data-endpoint="songs"></div> <div class="menu-content menu-artists" data-endpoint="artists"></div> <div class="menu-content menu-musicalStyles" data-endpoint="genres"></div> <div class="menu-content menu-playlists" data-endpoint="playlists"></div> <div class="menu-content menu-spotify" data-endpoint="spotify" data-loaded="1"> <div class="menu-spotify-content"> <p class="menu-spotify-title font --base --size20">Búsqueda rápida con Spotify</p> <p class="menu-spotify-description font --base --size14">Mira la letra de lo que estás escuchando.</p> <button class="menu-spotify-connect js-spotify-button">Conectar Spotify</button> </div> </div> <div class="menu-content menu-dictionary" data-endpoint="dictionary"></div> <div class="menu-content menu-blog" data-endpoint="blog"></div> <div class="menu-content menu-apps" data-endpoint="" data-loaded="1"> <div class="menu-title font --base --size16">Aplicaciones y plugins</div> <div class="menu-apps-mobile"> <i>Teléfono móvil</i> <a class="menu-apps-playStore" href="https://play.google.com/store/apps/details?id=com.st ...
# <button class="chip --outline" data-ga-label="playlists" data-tab="user-playlists">
# <strong class="chip-label font --base --strong --size14">Playlists</strong>
# </button>
# <button class="chip --outline" data-ga-label="artistas" data-tab="user-artists">
# <strong class="chip-label font --base --strong --size14">Artistas</strong>
# </button>
# <button class="chip --outline" data-ga-label="albuns" data-tab="user-albums">
# <strong class="chip-label font --base --strong --size14">Álbumes</strong>
# </button>
# <button class="chip --outline" data-ga-label="notificacoes" data-tab="user-notifications">
# <strong class="chip-label font --base --strong --size14">Notificaciones</strong>
# <span class="js-n-n font"></span>
# </button>
# <button class="chip --outline" data-ga-label="amigos" data-tab="user-friends">
# <strong class="chip-label font --base --strong --size14">Amigos pendientes</strong>
# <span class="js-fr-n font"></span>
# </button> </div></div> <div class="user-content user-playlists" data-endpoint="playlists"> <div class="user-playlists-list on ps"> <ul class="player-list user-playlists-default --owner" id="ccid_playlist-list"></ul> </div> <div class="user-playlistSongs-list ps"> <div class="user-playlistSongs-header" id="js-playlist-header"> <button class="user-playlistSongs-return" id="js-playlist-return">Voltar</button> <b class="user-playlistSongs-title font --base --strong --size20"></b> <button class="user-playlists-listen button --listen" data-title="Ouvir" id="js-user-menu-listen">Escuchar</button> </div> <ul class="player-list hasCounterReset playlistSongs-items" id="ccid_playlist-view"></ul> </div> </div> <div class="user-content user-artists" data-endpoint="artists"></div> <div class="user-content user-albums" data-endpoint="albums"></div> <div class="user-content user-notifications" data-endpoint="notifications"> <div class="ps"> <ul class="js-nt-list user-notifications-list"></ul> </div> </div> <div class="user-content user-friends" data-endpoint="friends"> <div class="ps js-fr-not"> <ul class="list ccid_notify_am"></ul> </div> </div> </div> </div> <script id="user_widget_send_template" type="text/template"> <a rel="nofollow" href="/contribuicoes/">Enviar letra</a> </script> <script id="user_widget_template" type="text/template"> <a class="js-user-open-login font --base --strong --size16" href="#" data-ga-label="entrar">Iniciar sesión</a> </script> <script id="user_widget_auth_template" type="text/template"> <a href="/membros/%id%/" class="header-user" data-ga-label="usuario"> <span class="font --base --size16 --strong">%nickname%</span>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="thumbnail --skin-image --shape-circle --size-xSmall --tabletSize-xSmall">
#     <img
#
#             src="%avatar%"
#
#
#         alt="%nickname%"
#
#
#
#
#
#     >
# </div> <i class="unreadNotifications" style="display:none" alt=""></i> </a> </script> <script id="notification_fr_template" type="text/template"> <li data-userid="%userID%" data-id="%id%" class="%className%" > <a class="js-user-notification font --base --size14" href="/membros/%userID%/"> <img data-original="%userAvatar%" data-lazy="true" alt="" width="32" height="32"> <b>%userName%</b> </a> <div class="user-notifications-buttons"> <button data-type="confirm" class="js-confirm ccid_notify_ac">Aceptar</button> <button data-type="ignore" class="js-decline ccid_notify_ig">Ignorar</button> </div> </li> </script> <script id="widget_playlists_template" type="text/template"> <li class="user-playlists-item"> <span id="js-user-menu-listen" data-endpoint="%endpoint%" data-credentials="%credentials%" data-visibility="%visibility%" class="user-playlists-play"></span> <a href="#" data-endpoint="%endpoint%" data-credentials="%credentials%" data-visibility="%visibility%"> <span>%name%</span> </a> <button style="display:%displayEdit%" class="button -edit plt_edit user-playlist-edit font --base --size12" data-hash="%hash%" data-endpoint="%endpoint%" data-credentials="%credentials%" data-visibility="%visibility%">editar</button> </li> </script> <script id="widget_songs_template" type="text/template"> <li> <a href="/%dns%/%url%/#%hash%" class="font --base --size14"> <span class="bt-play"></span> <p>%artist% - <span>%name%</span></p> </a> </li> </script> </div> </div> </header> <div class="page-home" id="all"> <div id="cnt_top"> <div class="--full gridContainer withRefresh an" data-refresh="30" id="pub_25" style="display:none;"><div id="pub_25_ad_refresh"><div id="pub_25_ad"></div></div></div> <div class="--outpage an" id="pub_6" style="display:flex;"><div id="pub_6_ad"></div></div> <div class="homeFilter gridContainer js-genre-filter"> <div class="filter"> <div class="filter-tabs">
# <a class="chip --outline isOn js-tab-link" data-genre="0" data-slug="" href="/">
# <strong class="chip-label font --base --strong --size14">Todos</strong>
# </a>
# <a class="chip --outline js-tab-link" data-genre="4" data-slug="pop" href="/estilos/pop/">
# <strong class="chip-label font --base --strong --size14">Pop</strong>
# </a>
# <a class="chip --outline js-tab-link" data-genre="47" data-slug="reggaeton" href="/estilos/reggaeton/">
# <strong class="chip-label font --base --strong --size14">Reggaeton</strong>
# </a>
# <a class="chip --outline js-tab-link" data-genre="666" data-slug="rock" href="/estilos/rock/">
# <strong class="chip-label font --base --strong --size14">Rock</strong>
# </a>
# <a class="chip --outline js-tab-link" data-genre="6" data-slug="romantico" href="/estilos/romantico/">
# <strong class="chip-label font --base --strong --size14">Música Romántica</strong>
# </a> <div class="filter-tabs-more js-cnt-filter-more-genre">
# <button class="chip --outline --dropdown js-filter-more-genre" data-default="Más" data-genre="0" data-slug="">
# <strong class="chip-label font --base --strong --size14">  Más  </strong>
# </button> <div class="filter-more-dropdown modal js-cnt-filter_drop-genre" data-endpoint="/v2/genres/" data-placeholder="Digita el género musical"></div> </div> </div> </div> </div> <div class="homeHighlight gridContainer"> <a class="homeHighlight-link" data-ctr="hl_10380" href="https://www.letras.com/paulo-londra/itamambuca-part-luisa-sonza/#legenda" id="highlight"> <img alt="" class="homeHighlight-image" height="320" src="https://akamai.sscdn.co/uploadfile/letras/imagem_destaques/10380_es_ES_a7bfcc4.jpg" srcset="https://akamai.sscdn.co/uploadfile/letras/imagem_destaques/10380_es_ES_a7bfcc4.jpg 1x, https://akamai.sscdn.co/uploadfile/letras/imagem_destaques/10380_es_ES_a7bfcc4_2x.jpg 2x" width="1055"/> <span class="button --listen">¡Argentina, Brasil y un temazo! Escúchalo con la letra y canta  🌊</span> </a> </div> <script>window._hlc=[{"Name":"hlv-sp-10380","Value":"1","Expires":1736799380443}];</script> <div class="--full gridContainer withRefresh an" data-refresh="30" id="pub_4" style="display:flex;"><div id="pub_4_ad_refresh"><div id="pub_4_ad"></div></div></div> <div data-page="home" id="js-cnt-tops"> <div class="homeTops gridContainer"> <a class="sectionHeader" href="/mais-acessadas/"> <h2>Los más vistos </h2> </a> <div class="homeTops-content js-cnt-target"> <ol class="top-list_mus"> <li> <a href="/villancicos/ya-vienen-los-reyes-magos/" title="Ya Vienen Los Reyes Magos"> <b class="font --base --strong --size16">Ya Vienen Los Reyes Magos</b> <span class="font --base --size14">Villancicos</span> </a> </li> <li> <a href="/bad-bunny/dtmf/" title="DtMF"> <b class="font --base --strong --size16">DtMF</b> <span class="font --base --size14">Bad Bunny</span> </a> </li> <li> <a href="/bad-bunny/baile-inolvidable/" title="BAILE INoLVIDABLE"> <b class="font --base --strong --size16">BAILE INoLVIDABLE</b> <span class="font --base --size14">Bad Bunny</span> </a> </li> <li> <a href="/lady-gaga/die-with-a-smile-feat-bruno-mars/" title="Die With A Smile (feat. Bruno Mars)"> <b class="font --base --strong --size16">Die With A Smile (feat. Bruno Mars)</b> <span class="font --base --size14">Lady Gaga</span> </a> </li> <li> <a href="/lola-young/messy/" title="Messy"> <b class="font --base --strong --size16">Messy</b> <span class="font --base --size14">Lola Young</span> </a> </li> <li> <a href="/rose/apt-feat-bruno-mars/" title="APT. (feat. Bruno Mars)"> <b class="font --base --strong --size16">APT. (feat. Bruno Mars)</b> <span class="font --base --size14">ROSÉ</span> </a> </li> <li> <a href="/bad-bunny/nuevayol/" title="NUEVAYoL"> <b class="font --base --strong --size16">NUEVAYoL</b> <span class="font --base --size14">Bad Bunny</span> </a> </li> <li> <a href="/bad-bunny/velda-part-omar-courtz-y-dei-v/" title="VeLDÁ (part. Omar Courtz y Dei V)"> <b class="font --base --strong --size16">VeLDÁ (part. Omar Courtz y Dei V)</b> <span class="font --base --size14">Bad Bunny</span> </a> </li> <li> <a href="/bad-bunny/voy-a-llevarte-pa-pr/" title="VOY A LLeVARTE PA PR"> <b class="font --base --strong --size16">VOY A LLeVARTE PA PR</b> <span class="font --base --size14">Bad Bunny</span> </a> </li> <li> <a href="/bad-bunny/turista/" title="TURiSTA"> <b class="font --base --strong --size16">TURiSTA</b> <span class="font --base --size14">Bad Bunny</span> </a> </li> </ol> <ol class="top-list_art homeTops-content-artistList"> <li><a href="/bad-bunny/">
# <div class="thumbnail --skin-image --shape-circle --size-xLarge --tabletSize-xLarge">
# <img alt="" src="https://akamai.sscdn.co/uploadfile/letras/fotos/0/1/c/a/01ca515bab1922f75a1ec653c547345c-tb5.jpg"/>
# </div> <b class="font --base --strong --size18">Bad Bunny</b> </a></li> <li><a href="/villancicos/">
# <div class="thumbnail --skin-image --shape-circle --size-xLarge --tabletSize-xLarge">
# <img alt="" src="https://akamai.sscdn.co/uploadfile/letras/fotos/e/d/2/3/ed23a91e563fd4a2abf015b736da4461-tb5.jpg"/>
# </div> <b class="font --base --strong --size18">Villancicos</b> </a></li> <li><a href="/taylor-swift/">
# <div class="thumbnail --skin-image --shape-circle --size-xLarge --tabletSize-xLarge">
# <img alt="" src="https://akamai.sscdn.co/uploadfile/letras/fotos/1/0/7/b/107bbb36057fbb04a080ee950632d372-tb5.jpg"/>
# </div> <b class="font --base --strong --size18">Taylor Swift</b> </a></li> </ol> </div> </div> </div> <section class="homeBestOfThree gridContainer"> <h2 class="sectionHeader">Crea playlists con tus artistas favoritos</h2> <div class="homeCreateMix gridContainer"> <div class="homeCreateMix-suggest suggest"> <div class="tagsInput"> <label class="tagsInput-label" for="home-suggest-search"> <input aria-label="Búsqueda de artistas" autocomplete="off" class="tagsInput-input font --base --strong --size18" id="home-suggest-search" placeholder="Agrega tus artistas" type="search"/> <span class="tagsInput-counter font --base --strong --size14"></span> <button class="tagsInput-clearButton" title="Limpar"> <i></i> </button> </label> </div> <div class="suggest-drop modal"> <ul class="cnt-list-check"></ul> <div class="checked-items"></div> </div> </div> <button class="homeCreateMix-submit button --listen --large font --base --strong --size18 isInactive">Escuchar mi playlist</button> </div> <h3 class="sectionHeader --small">¿Sin ideas? Comienza por aquí</h3> <div class="homeBestOfThree-items"> <a class="homeBestOfThree-item" data-ctr="bundle_259" href="/radio.html?artists=maria-elena-walsh,javier-solis,espinoza-paz"> <img alt="" class="homeBestOfThree-item-image" data-lazy="" data-original="https://akamai.sscdn.co/uploadfile/letras/playlists/798f6627549e62b5203a1c8e48e766b9.jpg" height="191" src="..." width="191"/> <div class="homeBestOfThree-item-content"> <strong class="homeBestOfThree-item-gender font --base --strong --size12">Ranchera</strong> <b class="homeBestOfThree-item-artists font --base --strong --size16">Javier Solis + María Elena Walsh + Espinoza Paz</b> <span class="button --listen">Escuchar playlist</span> </div> </a> <a class="homeBestOfThree-item" data-ctr="bundle_222" href="/radio.html?artists=alejandro-sanz,jason-mraz,venegas-julieta"> <img alt="" class="homeBestOfThree-item-image" data-lazy="" data-original="https://akamai.sscdn.co/uploadfile/letras/playlists/76b2d24f9bfec8fb4de3c6ee45ee0baf.jpg" height="191" src="..." width="191"/> <div class="homeBestOfThree-item-content"> <strong class="homeBestOfThree-item-gender font --base --strong --size12">Pop</strong> <b class="homeBestOfThree-item-artists font --base --strong --size16">Julieta Venegas + Alejandro Sanz + Jason Mraz</b> <span class="button --listen">Escuchar playlist</span> </div> </a> <a class="homeBestOfThree-item" data-ctr="bundle_262" href="/radio.html?artists=bob-marley,manu-chao,soja"> <img alt="" class="homeBestOfThree-item-image" data-lazy="" data-original="https://akamai.sscdn.co/uploadfile/letras/playlists/7893897bec2307a34385c9b4d96ed866.jpg" height="191" src="..." width="191"/> <div class="homeBestOfThree-item-content"> <strong class="homeBestOfThree-item-gender font --base --strong --size12">Reggae</strong> <b class="homeBestOfThree-item-artists font --base --strong --size16">Bob Marley + Manu Chao + Soja</b> <span class="button --listen">Escuchar playlist</span> </div> </a> <a class="homeBestOfThree-item" data-ctr="bundle_305" href="/radio.html?artists=paula-fernandes,jorge-mateus,victor-leo"> <img alt="" class="homeBestOfThree-item-image" data-lazy="" data-original="https://akamai.sscdn.co/uploadfile/letras/playlists/8c93aa88696c2b5ac643a77037c13b5a.jpg" height="191" src="..." width="191"/> <div class="homeBestOfThree-item-content"> <strong class="homeBestOfThree-item-gender font --base --strong --size12">Sertanejo</strong> <b class="homeBestOfThree-item-artists font --base --strong --size16">Paula Fernandes + Victor e Leo + Jorge e Mateus</b> <span class="button --listen">Escuchar playlist</span> </div> </a> </div> </section> <div class="homePlaylists gridContainer"> <h2 class="sectionHeader"> <a class="sectionHeader-link" href="/playlists.html">Playlists para cantar</a> </h2> <ul class="homePlaylists-playlists">
# <li class="u-flex1">
# <a class="mediaList-item --playlist" data-ctr="playlist_1357272" href="/playlists/1357272/">
# <em class="mediaList-item-imageContainer">
# <div class="thumbnail --skin-image --shape-rectangle --size-proportional --tabletSize-proportional">
# <img alt="" data-lazy="" data-original="https://akamai.sscdn.co/uploadfile/letras/playlists/e/2/7/4/e274910e79554a2b981adad90c380485.jpg" src="..."/>
# </div>
# </em>
# <div class="mediaList-item-content">
# <b class="mediaList-item-primaryText u-truncate3 font --base --size16 --mobileSize14">30 éxitos de la música Dance</b>
# <span class="mediaList-item-secondaryText font --base --size14 --mobileSize12">
#
#                     Corona, Haddaway, Cascada...
#
#             </span>
# </div>
# </a>
# </li>
# <li class="u-flex1">
# <a class="mediaList-item --playlist" data-ctr="playlist_1373227" href="/playlists/1373227/">
# <em class="mediaList-item-imageContainer">
# <div class="thumbnail --skin-image --shape-rectangle --size-proportional --tabletSize-proportional">
# <img alt="" data-lazy="" data-original="https://akamai.sscdn.co/uploadfile/letras/playlists/9/2/0/0/9200298fccf846069d964b29c675c05d.jpg" src="..."/>
# </div>
# </em>
# <div class="mediaList-item-content">
# <b class="mediaList-item-primaryText u-truncate3 font --base --size16 --mobileSize14">Baladas del Rock: grandes éxitos</b>
# <span class="mediaList-item-secondaryText font --base --size14 --mobileSize12">
#
#                     KISS, Guns N' Roses, Queen y otros
#
#             </span>
# </div>
# </a>
# </li>
# <li class="u-flex1">
# <a class="mediaList-item --playlist" data-ctr="playlist_1282191" href="/playlists/1282191/">
# <em class="mediaList-item-imageContainer">
# <div class="thumbnail --skin-image --shape-rectangle --size-proportional --tabletSize-proportional">
# <img alt="" data-lazy="" data-original="https://akamai.sscdn.co/uploadfile/letras/playlists/9/9/d/e/99de2d0aed6d442fa511945362678962.jpg" src="..."/>
# </div>
# </em>
# <div class="mediaList-item-content">
# <b class="mediaList-item-primaryText u-truncate3 font --base --size16 --mobileSize14">Música para limpiar la casa</b>
# <span class="mediaList-item-secondaryText font --base --size14 --mobileSize12">
#
#                     Shakira, Adele, Queen...
#
#             </span>
# </div>
# </a>
# </li>
# <li class="u-flex1">
# <a class="mediaList-item --playlist" data-ctr="playlist_1328898" href="/playlists/1328898/">
# <em class="mediaList-item-imageContainer">
# <div class="thumbnail --skin-image --shape-rectangle --size-proportional --tabletSize-proportional">
# <img alt="" data-lazy="" data-original="https://akamai.sscdn.co/uploadfile/letras/playlists/a/4/4/8/a4486c374a9a4ab09da8f5417280203c.jpg" src="..."/>
# </div>
# </em>
# <div class="mediaList-item-content">
# <b class="mediaList-item-primaryText u-truncate3 font --base --size16 --mobileSize14">101 cantantes mujeres latinas e hispanas</b>
# <span class="mediaList-item-secondaryText font --base --size14 --mobileSize12">
#
#                     Shakira, Mercedes Sosa, Celia Cruz...
#
#             </span>
# </div>
# </a>
# </li>
# </ul> </div> <script>window._phlc=[{"Name":"phlv-sp-15257","Value":"1","Expires":1736799380444}];</script> <div class="homeLatestNews gridContainer dummy js-ajax-include" data-src="/latestnews.html?page=home"> <a class="sectionHeader" href="/blog/">Lee en el blog</a> <div class="homeLatestNews-news"> <div class="mediaList-item"> <em class="mediaList-item-imageContainer">
# <div class="thumbnail --skin-image --shape-rectangle --size-proportional --tabletSize-proportional">
# <img alt="" data-lazy="" src="..."/>
# </div> </em> <b></b> <b></b> <b></b> </div> <div class="mediaList-item"> <em class="mediaList-item-imageContainer">
# <div class="thumbnail --skin-image --shape-rectangle --size-proportional --tabletSize-proportional">
# <img alt="" data-lazy="" src="..."/>
# </div> </em> <b></b> <b></b> <b></b> </div> <div class="mediaList-item"> <em class="mediaList-item-imageContainer">
# <div class="thumbnail --skin-image --shape-rectangle --size-proportional --tabletSize-proportional">
# <img alt="" data-lazy="" src="..."/>
# </div> </em> <b></b> <b></b> <b></b> </div> <div class="mediaList-item"> <em class="mediaList-item-imageContainer">
# <div class="thumbnail --skin-image --shape-rectangle --size-proportional --tabletSize-proportional">
# <img alt="" data-lazy="" src="..."/>
# </div> </em> <b></b> <b></b> <b></b> </div> </div> </div> <div class="--full gridContainer with-lazy withRefresh an" data-refresh="30" id="pub_1" style="display:flex;"><div id="pub_1_ad_refresh"><div id="pub_1_ad"></div></div></div> <section class="homeRecommendedSongs gridContainer dummy js-ajax-include" data-notify-parent="" data-src="/recommended_songs.ssi?page=home"> <h2 class="sectionHeader">Canciones recomendadas</h2> <div class="homeRecommendedSongs-songs"> <div class="homeRecommendedSongs-song container"> <img alt="" height="44" src="..." width="44"/> <div class="homeRecommendedSongs-info"> <b class="homeRecommendedSongs-title font --base --strong --size16"></b> <span class="homeRecommendedSongs-artist"></span> </div> </div> <div class="homeRecommendedSongs-song container"> <img alt="" height="44" src="..." width="44"/> <div class="homeRecommendedSongs-info"> <b class="homeRecommendedSongs-title font --base --strong --size16"></b> <span class="homeRecommendedSongs-artist"></span> </div> </div> <div class="homeRecommendedSongs-song container"> <img alt="" height="44" src="..." width="44"/> <div class="homeRecommendedSongs-info"> <b class="homeRecommendedSongs-title font --base --strong --size16"></b> <span class="homeRecommendedSongs-artist"></span> </div> </div> <div class="homeRecommendedSongs-song container"> <img alt="" height="44" src="..." width="44"/> <div class="homeRecommendedSongs-info"> <b class="homeRecommendedSongs-title font --base --strong --size16"></b> <span class="homeRecommendedSongs-artist"></span> </div> </div> <div class="homeRecommendedSongs-song container"> <img alt="" height="44" src="..." width="44"/> <div class="homeRecommendedSongs-info"> <b class="homeRecommendedSongs-title font --base --strong --size16"></b> <span class="homeRecommendedSongs-artist"></span> </div> </div> <div class="homeRecommendedSongs-song container"> <img alt="" height="44" src="..." width="44"/> <div class="homeRecommendedSongs-info"> <b class="homeRecommendedSongs-title font --base --strong --size16"></b> <span class="homeRecommendedSongs-artist"></span> </div> </div> </div> </section> <section class="homeRecommendedAlbums gridContainer dummy js-ajax-include" data-src="/albums.ssi?page=home&amp;slug=" data-use-cache-for-logged-off="true"> <a class="sectionHeader" href="/top-albuns/"> <h2>Álbumes recomendados</h2> </a> <div class="homeRecommendedAlbums-albums js-cnt-target"> <div class="mediaList-item --album"> <em class="mediaList-item-imageContainer">
# <div class="thumbnail --skin-image --shape-square --size-proportional --tabletSize-proportional">
# <img alt="" data-lazy="" src="..."/>
# </div> </em> <b></b> <span></span> </div> <div class="mediaList-item --album"> <em class="mediaList-item-imageContainer">
# <div class="thumbnail --skin-image --shape-square --size-proportional --tabletSize-proportional">
# <img alt="" data-lazy="" src="..."/>
# </div> </em> <b></b> <span></span> </div> <div class="mediaList-item --album"> <em class="mediaList-item-imageContainer">
# <div class="thumbnail --skin-image --shape-square --size-proportional --tabletSize-proportional">
# <img alt="" data-lazy="" src="..."/>
# </div> </em> <b></b> <span></span> </div> <div class="mediaList-item --album"> <em class="mediaList-item-imageContainer">
# <div class="thumbnail --skin-image --shape-square --size-proportional --tabletSize-proportional">
# <img alt="" data-lazy="" src="..."/>
# </div> </em> <b></b> <span></span> </div> <div class="mediaList-item --album"> <em class="mediaList-item-imageContainer">
# <div class="thumbnail --skin-image --shape-square --size-proportional --tabletSize-proportional">
# <img alt="" data-lazy="" src="..."/>
# </div> </em> <b></b> <span></span> </div> <div class="mediaList-item --album"> <em class="mediaList-item-imageContainer">
# <div class="thumbnail --skin-image --shape-square --size-proportional --tabletSize-proportional">
# <img alt="" data-lazy="" src="..."/>
# </div> </em> <b></b> <span></span> </div> </div> </section> <section class="homeRecommendedArtists gridContainer dummy js-ajax-include" data-lazy="true" data-src="/recommended_artists.ssi?page=home" data-threshold="300" data-use-cache-for-logged-off="true"> <h2 class="sectionHeader">Artistas recomendados</h2> <ul class="homeRecommendedArtists-artists"> <li> <div class="homeRecommendedArtists-artists-link"> <img alt="" height="75" src="..." width="75"/> <span> <b class="font --base --strong --size18"></b> <small class="font --base --size14"></small> </span> </div> </li> <li> <div class="homeRecommendedArtists-artists-link"> <img alt="" height="75" src="..." width="75"/> <span> <b class="font --base --strong --size18"></b> <small class="font --base --size14"></small> </span> </div> </li> <li> <div class="homeRecommendedArtists-artists-link"> <img alt="" height="75" src="..." width="75"/> <span> <b class="font --base --strong --size18"></b> <small class="font --base --size14"></small> </span> </div> </li> <li> <div class="homeRecommendedArtists-artists-link"> <img alt="" height="75" src="..." width="75"/> <span> <b class="font --base --strong --size18"></b> <small class="font --base --size14"></small> </span> </div> </li> <li> <div class="homeRecommendedArtists-artists-link"> <img alt="" height="75" src="..." width="75"/> <span> <b class="font --base --strong --size18"></b> <small class="font --base --size14"></small> </span> </div> </li> <li> <div class="homeRecommendedArtists-artists-link"> <img alt="" height="75" src="..." width="75"/> <span> <b class="font --base --strong --size18"></b> <small class="font --base --size14"></small> </span> </div> </li> </ul> </section> <div class="homeGenrePlaylists gridContainer dummy js-ajax-include" data-lazy="true" data-src="/genres.ssi" data-threshold="200" data-use-cache-for-logged-off="true"> <h2 class="sectionHeader"> <a class="sectionHeader-link" href="/playlists.html">Tus estilos en forma de playlist</a> <a class="button -seeMore -block" href="/playlists.html">Ver más playlists</a> </h2> <ul class="homeGenrePlaylists-playlists"> <div class="mediaList-item"> <div class="mediaList-item-imageContainer">
# <div class="thumbnail --skin-image --shape-rectangle --size-proportional --tabletSize-proportional">
# <img alt="" src="data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20width='100'%20height='56'/%3E"/>
# </div> </div> <div class="mediaList-item-content"> <strong></strong> <span></span> </div> </div> <div class="mediaList-item"> <div class="mediaList-item-imageContainer">
# <div class="thumbnail --skin-image --shape-rectangle --size-proportional --tabletSize-proportional">
# <img alt="" src="data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20width='100'%20height='56'/%3E"/>
# </div> </div> <div class="mediaList-item-content"> <strong></strong> <span></span> </div> </div> <div class="mediaList-item"> <div class="mediaList-item-imageContainer">
# <div class="thumbnail --skin-image --shape-rectangle --size-proportional --tabletSize-proportional">
# <img alt="" src="data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20width='100'%20height='56'/%3E"/>
# </div> </div> <div class="mediaList-item-content"> <strong></strong> <span></span> </div> </div> <div class="mediaList-item"> <div class="mediaList-item-imageContainer">
# <div class="thumbnail --skin-image --shape-rectangle --size-proportional --tabletSize-proportional">
# <img alt="" src="data:image/svg+xml,%3Csvg%20xmlns='http://www.w3.org/2000/svg'%20width='100'%20height='56'/%3E"/>
# </div> </div> <div class="mediaList-item-content"> <strong></strong> <span></span> </div> </div> </ul> </div> </div> <div id="cnt_footer"> <div class="--full gridContainer with-lazy withRefresh an" data-refresh="30" id="pub_9" style="display:flex;"><div id="pub_9_ad_refresh"><div id="pub_9_ad"></div></div></div> </div> </div> <div class="player" id="player"></div> <div class="playerNotification font --base --size14"></div> <div class="modal contextualPlanModal" id="js-contextualPlanModal" style="transform: translate(0, 100%)"> <h3 class="contextualPlanModal-title font --base --strong --size24 --mobileSize20">Navegue sem anúncios</h3> <button class="contextualPlanModal-closeButton" id="js-contextualPlanModal-close"> Fechar </button> <p class="contextualPlanModal-subtitle font --copy --size14 contextualPlanModal-spaceBottom"> Curta as suas músicas sem interrupções </p> <div class="contextualPlanModal-divider --withText contextualPlanModal-text contextualPlanModal-spaceBottom font --base --size12"> <p>Pague uma vez e <strong class="font --base --strong --size12">use por um ano inteiro</strong></p> </div> <div class="contextualPlanModal-cards contextualPlanModal-spaceBottom"> <div class="contextualPlanCard --premium"> <div class="contextualPlanCard-header"> <i class="contextualPlanCard-header-image"></i> <p class="contextualPlanCard-header-text isLoading"> <span class="header-text-currency font --base --strong --size10">R$</span> <span class="header-text-priceInteger font --base --strong --size24"></span> <span class="header-text-priceCents font --base --strong --size24"></span> <span class="header-text-period font --base --strong --size14">/ano</span> </p> </div> <p class="contextualPlanCard-description font --base --regular --size16">Use o Letras sem anúncios.</p> <div class="contextualPlanCard-button isLoading"> <span></span> </div> </div> <div class="contextualPlanCard --academy"> <div class="contextualPlanCard-header"> <i class="contextualPlanCard-header-image"></i> <div class="tag --fill --absolute --academyPrimary --xSmall"> <span class="tag-label font --base --size12 --strong"> Mejor opción 🔥 </span> </div> <p class="contextualPlanCard-header-text isLoading"> <span class="header-text-currency font --base --strong --size10">R$</span> <span class="header-text-priceInteger font --base --strong --size24"></span> <span class="header-text-priceCents font --base --strong --size24"></span> <span class="header-text-period font --base --strong --size14">/ano</span> </p> </div> <p class="contextualPlanCard-description font --base --regular --size16">Benefícios Premium + aulas de idiomas com música.</p> <div class="contextualPlanCard-button isLoading"> <span></span> </div> </div> </div> <a class="button -bold contextualPlanModal-button contextualPlanModal-spaceBottom font --base --strong --size12 js-comparePlans" href="/planos.html"> Compare os planos </a> <p class="contextualPlanModal-text font --base --size12"> Já é assinante? <a class="font --base --strong --size12" href="#">Faça login</a>. </p> </div> <div class="modalOverlay"></div> </div> <div id="js-scripts"> <script>_omq.push(['ui/home']);</script> </div> <footer class="footer u-contentVisibility-auto"> <div class="gridContainer"> <div class="footer-alphabet"> <strong class="footer-label --alphabet font --base --strong --size16">Todos los artistas</strong> <ul class="footer-alphabet-list"> <li class="footer-alphabet-item font --base --size16"> <a href="/letra/A/">A</a> </li> <li class="footer-alphabet-item font --base --size16"> <a href="/letra/B/">B</a> </li> <li class="footer-alphabet-item font --base --size16"> <a href="/letra/C/">C</a> </li> <li class="footer-alphabet-item font --base --size16"> <a href="/letra/D/">D</a> </li> <li class="footer-alphabet-item font --base --size16"> <a href="/letra/E/">E</a> </li> <li class="footer-alphabet-item font --base --size16"> <a href="/letra/F/">F</a> </li> <li class="footer-alphabet-item font --base --size16"> <a href="/letra/G/">G ...
# <hr class="divider --small u-marginTop24 u-marginBottom24"/>
# <div class="footer-apps"> <div> <strong class="footer-label font --base --strong --size16">Aplicaciones</strong> <div class="footer-apps-list"> <a aria-label="Google Play Store" class="footer-apps-store --googlePlay" href="https://play.google.com/store/apps/details?id=com.studiosol.player.letras&amp;hl=es" rel="noopener" target="_blank"><i></i></a> <a aria-label="App Store" class="footer-apps-store --appStore" href="https://itunes.apple.com/es/app/letras.mus.br/id773347891?mt=8" rel="noopener" target="_blank"><i></i></a> </div> </div> <div> <div class="footer-apps-extension"> <strong class="footer-label font --base --strong --size16">Extensión</strong> <div class="footer-apps-list"> <a aria-label="Extensión para Google Chrome" class="footer-apps-chrome" href="/plugin/chrome/"><i></i></a> </div> </div> <div> <strong class="footer-label font --base --strong --size16">Ubicación e idioma</strong> <div class="footer-locale"> <div> <button class="js-select footer-select footer-locale-select font --base --size14" data-menu="region"> España </button> <div class="js-selectOptions footer-selectOptions" data-menu="region"> <button data-value="ar"> Argentina </button> <button data-value="pt"> Brasil </button> <button data-value="co"> Colombia </button> <button class="isSelected" data-value="sp"> España </button> <button data-value="es"> Hispanoamérica </button> <button data-value="mx"> México </button> </div> </div> <div> <button class="js-select footer-select footer-locale-select font --base --size14" data-menu="language"> Español </button> <div class="js-selectOptions footer-selectOptions" data-menu="language"> <button data-value="pt_BR"> Português </button> <button data-value="en_US"> English </button> <button class="isSelected" data-value="es_ES"> Español </button> </div> </div> </div> </div> </div> <div class="footer-theme"> <strong class="footer-label font --base --strong --size16">Tema</strong> <div> <button class="js-select footer-select footer-theme-select font --base --size14" data-menu="theme"> Automático </button> <div class="js-selectOptions footer-selectOptions" data-menu="theme"> <button data-value="auto">Automático</button> <button data-value="light">Claro</button> <button data-value="dark">Oscuro</button> </div> </div> </div> </div>
# <hr class="divider --small u-marginTop24 u-marginBottom24"/>
# <div class="footer-social g-fix"> <strong class="footer-label font --base --strong --size16">Sigue a Letras.com</strong> <div class="footer-follows"> <a class="footer-follow --instagram font --base --strong --size14" href="https://www.instagram.com/letrasmusbr/" rel="noopener" target="_blank"> <i></i> <span>Instagram</span> </a> <a class="footer-follow --tiktok font --base --strong --size14" href="https://www.tiktok.com/@letras" rel="noopener" target="_blank"> <i></i> <span>TikTok</span> </a> <a class="footer-follow --youtube font --base --strong --size14" href="https://www.youtube.com/letrasmusbr" rel="noopener" target="_blank"> <i></i> <span>YouTube</span> </a> <a class="footer-follow --facebook font --base --strong --size14" href="https://facebook.com/letraslatam" rel="noopener" target="_blank"> <i></i> <span>Facebook</span> </a> <a class="footer-follow --x font --base --strong --size14" href="https://x.com/letras" rel="noopener" target="_blank"> <i></i> <span>X</span> </a> <a class="footer-follow --pinterest font --base --strong --size14" href="https://br.pinterest.com/letrasmusbr" rel="noopener" target="_blank"> <i></i> <span>Pinterest</span> </a> <a class="footer-follow --linkedin font --base --strong --size14" href="https://www.linkedin.com/company/letras/" rel="noopener" target="_blank"> <i></i> <span>Linkedin</span> </a> </div> </div>
# <hr class="divider --small u-marginTop24 u-marginBottom24"/>
# <div class="footer-external"> <p class="footer-letrasText font --copy --size14"> <span> Música comienza con letras </span> <span> © 2003 - 2025, 3.5 millones de canciones </span> <span> Hecho con <b class="footer-letrasText-heart">amor</b> desde Brasil. </span> </p> <div class="footer-external-item"> <p class="footer-external-label">Más música en:</p> <div class="footer-external-links"> <a class="footer-external-link --cifraClub" href="https://www.cifraclub.com/">Cifra Club</a> <a class="footer-external-link --palco" href="https://www.palcomp3.com/">Palco MP3</a> </div> </div> </div> </div> <div id="js-footer-cmp"></div> </footer> <div class="modal editPlaylist" id="edit-playlist"> <div class="editPlaylist-content"> <h2 class="sectionHeader">Editar playlist</h2> <div class="editPlaylist-confirmation --delete"> <span>¿Seguro quieres eliminar esta playlist?</span> <button class="editPlaylist-deleteCancel">Cancelar</button> <button class="editPlaylist-deleteConfirm">Eliminar</button> </div> <div class="editPlaylist-confirmation --close"> <span>¿Seguro quieres salir sin guardar los cambios que hiciste?</span> <button class="editPlaylist-closeCancel">Cancelar</button> <button class="editPlaylist-closeConfirm">Salir sin guardar</button> </div> <div class="editPlaylist-actions"> <button class="editPlaylist-deleteButton font --base --size12">Eliminar playlist</button> <button class="button -bold editPlaylist-cancel">Cancelar</button> <button class="button -violet editPlaylist-save">Guardar</button> </div> <form class="editPlaylist-form"> <div class="editPlaylist-name"> <label class="label">Nombre</label> <input class="input editPlaylist-name-input" value=""/> <span class="editPlaylist-name-counter font --base --strong --size12"></span> </div> <div class="editPlaylist-visibility"> <label class="label">Quién puede escuchar esta lista</label> <div> <label class="editPlaylist-visibility-check font --base --size16"> <input checked="" class="radioButton-component --medium" name="visibility" type="radio" value="public"/><span>Todos</span> </label> <label class="editPlaylist-visibility-check font --base --size16"> <input checked="" class="radioButton-component --medium" name="visibility" type="radio" value="me"/><span>Solo yo</span> </label> </div> </div>
# <hr class="divider --large u-marginBottom20 editPlaylist-line"/>
# <div> <label class="label">Añadir canción</label> <div class="suggest"> <input autocomplete="off" class="s_input input" id="edit-playlist_suggest" placeholder="¿Qué canción quieres añadir?"/> <div class="suggest-drop modal"> <ul class="cnt-list-check"></ul> </div> </div> </div> </form> <div class="editPlaylist-results ps"> <ul class="cnt-list sortable"></ul> </div> </div> </div> <div class="modalOverlay js-edit-playlist-overlay"></div> <script id="edit_playlist_list_item" type="text/template"> <li data-lid="%id%" data-id="%playlistSongID%"> <span class="editPlaylist-selectOrder"> <select class="editPlaylist-selectOrder-select font --base --size16"></select> </span> <a href="#" data-nofollow="true"><b>%artist%</b> - %name%</a> <i class="x" title='eliminar'></i> </li> </script> <script id="modal_item_suggest" type="text/template"> <li data-lid="%imu%" data-dns="%dns%" data-url="%url%" data-name="%txt%%extra_txt%" data-art="%art%"> <a href="#">%art% - %txt%%extra_txt%</a> </li> </script> <script>
# 	if (!("IntersectionObserver" in window)) {
# 		var s = document.createElement("script");
# 		s.async = false;
# 		s.src = '//akamai.sscdn.co/letras/desktop/static/js/polyfills-es.v67ef72e4.js';
# 		document.head.appendChild(s);
# 	}
# </script>
# <script async="" src="https://akamai.sscdn.co/gcs/letras-static/ads/js/hb_letras.a8a120d3fd0a51977522.m.js" type="module"></script>
# <script async="" nomodule="" src="https://akamai.sscdn.co/gcs/letras-static/ads/js/hb_letras.1944109e970f9e33efd0.js"></script>
# <script async="" src="https://akamai.sscdn.co/gcs/letras-static/ads/js/prebid_all.a19a887425ce1bc88030f7519c3ea7f7.js"></script>
# <script async="" crossorigin="anonymous" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script async="" src="https://c.amazon-adsystem.com/aax2/apstag.js"></script>
# <script async="" src="//akamai.sscdn.co/letras/desktop/static/js/index.m-es.v0a73f26d.js" type="module"></script>
# <script async="" nomodule="" src="//akamai.sscdn.co/letras/desktop/static/js/index-es.v5b0a345f.js"></script>
# <script>(function (w, d, s, l, i) {
#     w[l] = w[l] || []; w[l].push({
#         'gtm.start':
#             new Date().getTime(), event: 'gtm.js'
#     }); var f = d.getElementsByTagName(s)[0],
#         j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#             'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
# })(window, document, 'script', 'dataLayer', 'GTM-KWMSHG8');
# window.dataLayer = window.dataLayer || [];</script>
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-KWMSHG8" style="display:none;visibility:hidden" width="0"></iframe></noscript> </body> </html>

# %%
nombre_letra=soup.find_all()
