# %% [markdown]
# # Histogramas, Binnings y Densidad

# %% [markdown]
# Un simple histograma puede ser un gran primer paso en la comprensión de un conjunto de datos.

# %%
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('ggplot')

data = np.random.randn(1000)

# %%
data
# Out:
# array([ 2.77661427e-01, -4.19308201e-01, -1.16508154e-01,  6.12949428e-01,
#         7.26748985e-01, -5.07129540e-02, -9.74755683e-01,  7.89698649e-01,
#         5.56952581e-02, -5.49355497e-01, -2.20661111e+00, -2.84562257e-01,
#        -4.05445069e-01, -2.56940499e+00, -5.76067915e-01, -4.83187160e-01,
#        -1.43584414e+00,  1.26280033e+00, -2.53928298e+00,  2.15658683e-01,
#        -1.01285970e+00,  1.02690796e+00, -1.51401751e+00, -4.49982496e-01,
#        -1.38365792e+00, -6.03072241e-01, -2.16908405e+00,  4.47273915e-02,
#         9.58198607e-02,  9.74552181e-01, -5.37772914e-01, -1.08682301e+00,
#        -1.32558036e+00, -1.49264093e-02,  2.00077043e+00,  1.21624866e+00,
#        -5.85189113e-01, -9.99756347e-01,  1.14202248e+00,  1.53352000e+00,
#        -6.32015187e-01, -3.21520088e-02, -1.13916464e-01, -6.91190648e-01,
#         9.06915200e-01, -2.13987124e+00, -1.01156593e+00,  2.88150905e-01,
#        -6.85198618e-01,  3.89138911e-01, -4.19075990e-01, -8.25442277e-01,
#        -1.34003740e+00,  5.94786489e-01, -2.38203658e-01,  1.16365889e+00,
#         6.19335964e-01, -8.24920816e-01,  9.66514285e-01,  1.29180572e-01,
#        -8.70998620e-01,  2.61016907e+00,  1.21182442e+00, -1.07015396e+00,
#        -1.18379567e+00,  5.57525108e-01, -5.20231245e-01,  1.74063135e-01,
#         9.12331846e-01,  4.89571556e-01,  1.01391534e+00,  1.79988576e-01,
#         4.62105851e-02, -9.15125290e-01, -6.85973362e-01, -7.63046325e-01,
#        -9.91899050e-01, -2.49396223e-01, -3.42310484e-01,  8.90367987e-01,
#        -1.11293894e+00, -6.98535631e-01,  1.07755023e+00,  5.01744220e-01,
#        -5.01812724e-01, -1.40329861e+00, -7.48998705e-01,  1.21716166e+00,
#        -5.90377682e-01,  3.98596244e-01, -8.98840301e-01, -1.61128168e+00,
#         2.10559410e+00,  8.29392919e-01, -8.84683646e-01,  3.23805584e-03,
#         1.23854986e+00, -1.35545296e-01,  1.13857123e+00,  1.64195110e+00,
#        -1.68269193e+00, -1.41783067e+00, -4.63614890e-02, -1.43823990e+00,
#         1.44691444e+00, -5.57443136e-01,  1.18843481e-01,  2.06361864e+00,
#         1.22820627e+00,  1.39376041e+00, -1.52138271e+00, -1.81764153e-01,
#        -8.64236815e-01, -3.32355309e-01, -6.09712419e-02,  5.69337724e-01,
#         5.04380284e-01,  7.11151520e-01, -2.03430302e-01,  9.51368688e-01,
#        -3.61025806e-01, -7.70542149e-01,  7.72130398e-01, -1.89834795e+00,
#        -1.15091649e+00, -5.19258686e-01,  5.04114999e-01, -1.16170277e+00,
#        -8.50657369e-02, -1.46197523e+00,  7.74480217e-01, -1.25267861e-01,
#         8.92372989e-01, -7.46463594e-01,  5.55068156e-01,  8.91980315e-01,
#         1.73866612e+00,  6.21202222e-02, -2.27027772e+00, -1.41098052e+00,
#         7.90289594e-01,  4.54123138e-01,  7.53716758e-01, -9.02250767e-01,
#         2.14215216e-01, -1.06871307e+00, -1.62948927e-01, -1.28544379e+00,
#         2.32236183e+00, -2.41371967e+00, -2.73665972e-01,  1.34287900e-01,
#         6.31725165e-02, -2.20341729e-01, -7.58674810e-01, -2.42842888e-01,
#         1.11180891e+00,  1.14627870e-01,  2.41119022e-01, -9.01688150e-01,
#         1.53365947e+00,  9.72765989e-02,  1.86657334e-01,  6.06570977e-01,
#         2.57173070e-02, -1.35840212e+00,  9.67829262e-01, -1.39726374e+00,
#         1.83395756e-01,  3.63639302e-01, -9.52237084e-01,  3.55842698e-01,
#        -4.96279847e-01,  8.92451133e-01, -2.93990050e-01, -1.24926751e+00,
#         2.67184046e-02,  1.05197275e+00,  1.91828402e+00, -1.42481872e+00,
#        -5.04542907e-01, -7.52108262e-01,  2.00998515e-01, -1.18311173e+00,
#        -1.59524110e+00,  1.32700925e+00, -2.40467697e+00,  4.35979858e-02,
#        -8.27226221e-01,  2.76300350e-01, -3.25384754e-02, -3.00996545e-01,
#         1.17859536e+00, -4.00086099e-01,  1.76603860e+00,  1.92248235e-01,
#         5.99409305e-01,  5.36672479e-01, -8.92200750e-01, -9.90300322e-01,
#        -1.17888019e+00,  1.74342534e+00,  1.64437350e-01,  1.14103755e+00,
#        -4.48430425e-01, -1.49551051e+00,  4.90340984e-01,  4.38427268e-01,
#        -3.07580621e-02,  1.03229856e+00, -1.79927970e+00, -1.90647968e+00,
#        -9.91150642e-01, -2.93208300e-02,  1.79083706e+00,  1.23903312e+00,
#        -1.46173951e+00, -5.63325015e-02, -3.98671344e-01, -1.28961171e+00,
#         6.24487511e-01, -6.45951558e-02,  1.05953830e+00, -9.70193603e-01,
#        -7.76538813e-01,  5.60877375e-01, -4.49338844e-01, -1.49097928e-01,
#         3.80310333e-02,  1.63721627e+00,  1.36343260e+00,  4.04969394e-01,
#         6.25097555e-01, -5.47211768e-01,  1.47249676e+00, -9.04362494e-01,
#        -2.31676420e+00, -4.55985507e-01, -8.96677835e-01, -2.82583574e-01,
#         2.62502753e-01,  8.19420778e-01, -5.17174419e-01, -7.21421540e-01,
#         8.12821844e-01, -1.50491805e+00, -2.71129912e-01,  1.38197253e+00,
#         7.53238211e-01, -3.66067846e-01, -7.66631306e-01, -1.11791163e+00,
#         1.79739239e+00, -8.13762972e-01, -1.24726574e+00, -4.77223567e-01,
#        -7.50409911e-01,  3.17794580e-01,  8.23090866e-01,  8.82205604e-01,
#         6.55393865e-01,  4.42173173e-01, -1.14219052e+00,  6.26498240e-01,
#        -4.86147096e-01, -6.32745096e-01,  3.17782968e-01,  9.24711546e-02,
#        -7.56111134e-01,  6.85365333e-01,  3.56161771e-01,  2.54001497e-01,
#        -1.19797579e+00, -1.36851470e+00,  9.72877103e-01, -6.88561887e-01,
#        -1.91738567e+00,  7.22097840e-01, -1.91890271e+00, -3.92920229e-01,
#         4.15397132e-01,  7.94942418e-01, -9.65014354e-01, -1.64548153e+00,
#         4.40092787e-01,  3.39221488e-01, -1.16157907e+00,  1.66492578e-01,
#        -3.55525038e-01, -1.54111924e+00,  2.99407225e-01,  1.61228518e+00,
#        -1.07171919e+00,  4.65288487e-02, -8.76494242e-01, -2.37016906e-01,
#        -8.23142711e-01,  1.33135846e-01,  4.05130011e-01, -1.86881149e-01,
#        -5.18472703e-03,  3.09083962e-01,  4.55014837e-01,  1.52261780e+00,
#        -1.52824539e+00,  3.98055872e-01,  1.40808797e-01, -1.39704700e-01,
#         2.27489389e+00,  2.98840360e-02,  7.58474050e-01, -1.46749630e-01,
#         2.08633793e-01, -4.21274342e-01,  1.38453076e-05,  3.89108357e-01,
#         4.45686357e-01, -9.57467214e-01,  5.55907868e-01,  8.34985940e-01,
#        -3.95577457e-01, -1.53685046e+00,  3.01974610e-01, -1.06514916e-01,
#         1.93104708e+00, -6.13343739e-01, -1.16222080e+00,  1.74465107e+00,
#         3.08978200e-01,  8.68470084e-01,  6.81303163e-01,  3.50768869e-01,
#         7.76949510e-01, -2.09698960e-01, -2.37600855e-01,  8.05329288e-01,
#        -4.47335045e-01, -4.62294767e-01,  2.72160263e-01,  1.80337838e+00,
#        -1.33904281e+00, -1.28082929e+00, -5.64662394e-01, -1.32255540e+00,
#        -9.76042028e-01,  9.94583046e-01, -3.67183688e-01,  4.13949431e-01,
#        -1.30826073e+00,  1.42410450e+00, -7.20345311e-01,  3.13075638e-01,
#         1.98837051e+00,  1.16761345e+00,  1.19333548e+00,  1.14335726e+00,
#         1.37078975e+00, -6.14926430e-01, -2.11906679e-01,  7.31260521e-01,
#         4.32246621e-02,  4.74518836e-02,  2.92402791e-01, -1.23974811e+00,
#         9.78864317e-01, -3.69979105e-01,  2.47395154e+00,  2.18165782e-01,
#         6.56639236e-01,  5.81004957e-01, -1.83754973e+00, -4.43788244e-01,
#         1.73575074e-01, -3.97773049e-01, -2.01262972e-02,  1.02379378e+00,
#        -6.29705047e-01, -1.20278843e+00,  7.90746465e-01, -1.71112980e+00,
#        -6.33402494e-01, -8.09737360e-01, -8.93628477e-01, -2.34615159e+00,
#         7.93741369e-01, -1.64840143e+00, -1.07642625e+00, -8.71715535e-01,
#        -1.77094495e-01,  1.92015288e+00, -9.58465642e-01,  5.03321650e-01,
#        -1.09504176e+00, -1.12065134e+00,  5.09088741e-01, -1.43560675e+00,
#        -7.36774450e-01,  2.47532435e-01, -2.18424984e+00, -2.04199352e-01,
#         4.08909697e-01,  9.28697999e-01, -3.39552261e-02, -7.94954996e-01,
#        -5.14316611e-03,  4.68739930e-03, -1.67282367e+00, -1.51952999e+00,
#         2.88779370e-01, -1.01159858e+00, -5.55209860e-01,  4.95141907e-01,
#         6.07970203e-01, -1.35100416e+00,  3.78563430e-01, -1.02577371e+00,
#         2.32282884e+00, -1.78404797e+00,  7.80846276e-01, -3.60761780e-01,
#         8.00613249e-01, -9.05036695e-01, -5.04124349e-01,  2.32051999e-01,
#         5.11201705e-01, -4.13219503e-01, -9.92078863e-02, -1.87068240e-01,
#        -9.70852321e-01,  5.22435348e-01,  5.74382959e-01,  1.38132404e+00,
#         5.84290731e-01, -1.53727348e+00, -2.26006291e-01, -1.35887491e-01,
#        -1.13654014e+00,  1.08620321e+00,  3.35880134e-01, -5.55194110e-01,
#         2.58625833e+00, -5.08015584e-01, -1.09745655e+00, -6.89280877e-01,
#        -7.96590630e-01,  1.32905617e+00, -6.95651039e-01,  5.83890708e-01,
#        -1.23726402e+00, -1.00984376e+00,  2.14984216e+00, -1.24855381e+00,
#        -5.78655303e-01, -1.62519658e+00, -1.44731056e+00,  3.52025986e-01,
#         8.27983025e-01,  1.77505616e+00, -1.32999865e+00, -1.56023093e+00,
#         3.50335699e-01, -1.90427529e+00, -7.56138876e-01, -1.43711035e+00,
#        -4.93247269e-01,  1.55792797e-01,  1.21325627e+00, -1.22449892e+00,
#         6.13399452e-01,  6.68178644e-01,  1.95714090e-01, -1.47202848e+00,
#         2.01845513e+00,  3.36460324e+00,  4.01097707e-01, -8.11834770e-01,
#        -1.93076261e-01, -2.81761030e-01, -6.99610130e-02,  3.02125781e-01,
#        -3.37410099e-01,  9.32051956e-01,  2.08536546e-01,  6.32350715e-01,
#         6.89636836e-01,  1.26498668e+00,  1.97075003e+00, -3.16805911e-01,
#        -6.33918914e-01, -5.59605941e-01,  3.29444100e-01, -1.32947133e+00,
#         5.17196149e-01, -7.64245631e-02, -2.42652667e+00, -6.64642731e-02,
#        -1.28150637e+00, -4.83682469e-01, -1.91206762e-01,  9.45356984e-01,
#         1.26187439e+00,  5.43964510e-01,  7.30093466e-01, -3.69998676e-01,
#         3.69180161e-01, -1.11017024e-02,  3.94491544e-01, -1.88926236e-01,
#         1.76162273e+00,  6.10725699e-01,  3.65641175e-01,  8.42726472e-01,
#        -1.74419134e-01, -1.30179032e+00, -1.69417186e+00,  8.18176289e-01,
#         1.61414158e-01,  4.50642317e-02,  1.26667378e+00, -1.02540483e+00,
#        -1.16313638e-01,  6.81572490e-01,  7.21829771e-01,  6.24768729e-01,
#        -1.47229853e+00,  6.83232975e-01, -2.31283251e+00,  1.10972225e+00,
#        -2.05802140e-01, -1.02760538e+00, -1.85059078e+00, -7.46075168e-01,
#        -1.76043656e+00,  3.04899676e-01,  1.95267888e+00,  3.22032701e-01,
#        -5.46089412e-01, -4.43123490e-01, -6.96102522e-01,  1.05792294e+00,
#        -4.37835661e-01, -1.14206885e-01, -9.07843731e-01, -1.13045845e+00,
#        -1.12594498e+00,  3.58096879e-01,  1.54104616e+00, -1.32493068e+00,
#         1.19580224e+00,  5.49691571e-01,  1.00717452e+00, -1.15419166e-01,
#        -1.65679257e+00,  1.02741294e+00, -2.05160719e-01, -5.32407261e-01,
#        -1.65660886e+00,  1.11950009e+00, -1.25929013e-01,  1.97900296e+00,
#        -1.15229105e+00,  7.10654134e-01, -1.89881147e-01,  5.09028733e-01,
#        -7.01949875e-01,  2.62030269e-01, -6.53046724e-01, -1.72171155e+00,
#         2.29014258e+00,  1.07736370e+00,  2.90282236e-01, -4.44882638e-01,
#        -4.03227447e-01,  2.52463513e-01, -3.80999042e-01, -3.61933349e-01,
#        -1.07165922e-01,  9.84133200e-02, -8.30953325e-01,  1.14235380e+00,
#        -2.27272128e+00,  1.40710178e+00, -9.69219109e-01, -3.37126310e-02,
#         5.71134096e-01,  6.52242763e-02, -3.35394748e-03,  1.31730712e-01,
#         3.69764124e+00, -6.96159155e-01, -5.32827995e-01,  7.62805657e-01,
#         1.78520630e+00,  9.85146089e-01,  9.01587185e-01, -8.88265506e-01,
#        -3.69340755e-01, -4.13799097e-01,  1.60887678e+00,  5.27440365e-01,
#         1.31185502e+00,  1.61230691e-01, -1.47437292e+00,  1.41614758e+00,
#        -4.85490263e-01,  8.46331346e-01,  8.72136717e-02,  2.51944103e-01,
#        -2.48538433e+00,  9.45420569e-01, -4.79701533e-01, -9.58602994e-01,
#         1.43836499e+00,  4.34475276e-01, -8.30627720e-01, -1.32887001e+00,
#        -1.51547268e+00, -3.69649971e-01,  1.31616752e+00, -1.46038107e-01,
#         1.84272968e+00,  4.98535260e-01,  5.64977693e-02,  1.53099435e+00,
#         5.96103927e-01, -1.32638227e-03, -1.52702789e-01, -4.32486696e-01,
#        -7.94668691e-01, -8.25086826e-01, -4.27154378e-01, -3.00408510e-01,
#        -8.56095168e-01,  5.57702530e-01,  1.14427534e+00, -1.54328839e+00,
#        -4.94604604e-02,  3.21359718e-03,  5.08832426e-01, -1.49928670e+00,
#        -4.55248279e-01, -6.53955266e-02,  1.95411320e+00, -2.00905706e+00,
#         8.24144598e-02,  7.46938687e-01, -2.76557362e+00, -1.64217510e-01,
#        -2.90972058e-01,  5.71999568e-01, -1.22955614e+00, -1.28973197e+00,
#         2.43003983e+00, -4.49490674e-01, -4.72677001e-01,  1.83300520e+00,
#         9.34322826e-01,  5.49963363e-02,  8.49659348e-02,  9.48762100e-01,
#         5.29807880e-01, -7.96262631e-01,  2.76957730e-01,  4.04700990e-02,
#         8.21286606e-01,  1.20473065e+00, -8.14653296e-02,  1.04101163e-01,
#        -1.95276518e+00,  1.48691048e+00,  9.70313528e-01, -4.20208629e-02,
#        -1.21643358e-01, -8.53238609e-01,  3.91886854e-01, -4.50920221e-01,
#         2.33600408e-01,  1.18662117e+00, -1.13291577e-01,  1.29933733e+00,
#         2.94434101e-01,  1.78535336e-01,  1.91271310e+00,  5.87246390e-01,
#         1.24616523e+00,  5.17714941e-01, -1.83822882e+00, -2.34095435e-01,
#         1.01210623e+00,  1.43621126e+00,  2.82150684e+00,  5.24380796e-01,
#         1.39358687e+00,  1.23621718e+00, -2.17517598e-01, -6.26007451e-01,
#        -1.07785433e+00,  1.42953211e+00, -8.51639154e-01, -9.44577309e-01,
#         6.79105545e-01, -9.37395716e-02,  1.94030741e-02, -9.29493161e-01,
#         6.08183778e-01,  5.56762775e-01,  1.16390314e+00,  1.56369251e+00,
#         6.74817822e-01,  5.61379121e-01,  1.49567800e+00,  5.74064253e-02,
#        -1.50094199e+00,  7.86023597e-01,  9.86674136e-01,  1.15880191e+00,
#         6.45555354e-01,  2.05285811e-01,  9.92291511e-02, -2.45963789e-01,
#         1.00660960e+00, -9.19402009e-01, -4.92750523e-01, -6.43862629e-01,
#         1.06100921e+00, -1.64330243e+00, -2.97606634e-01, -4.17512925e-01,
#         2.50094281e+00,  1.19036029e+00,  6.74516765e-01, -1.26323560e+00,
#        -1.08092179e+00,  1.19614527e-02,  1.16051727e+00,  5.54455622e-01,
#         5.76157848e-01,  5.37488819e-02,  4.19922890e-01,  2.83803996e-01,
#         1.13696760e+00,  3.87490737e-01, -5.79720378e-01,  3.78562247e-01,
#         6.97409997e-01,  8.27115996e-01, -8.02092278e-01,  1.09022836e-01,
#        -1.45422065e+00, -7.68538204e-01, -2.01393706e-01, -1.53992795e+00,
#        -5.76916559e-01,  4.79080484e-01,  1.12903686e-01,  5.52958324e-01,
#         6.67913844e-01,  7.39478824e-02,  1.08788729e+00, -1.12175017e+00,
#         6.37443582e-01, -1.16506665e+00,  1.03201971e+00,  8.38682708e-01,
#         9.87451827e-01, -1.14238362e+00, -5.29040744e-01, -1.53362228e+00,
#        -9.87656353e-01, -2.11999098e+00, -5.96931990e-01,  3.56717546e-01,
#        -1.24968163e+00,  3.05241088e-01, -2.99953046e-01,  3.42438708e-01,
#         1.47490258e+00, -1.12126171e-01,  5.85283050e-01, -4.99776789e-01,
#        -5.80194853e-01,  1.61667619e+00,  5.33987469e-02, -1.45710975e-01,
#         4.31193704e-01, -9.04014129e-01, -6.15410718e-01,  4.04417118e-01,
#        -1.51927299e+00, -5.57806038e-01,  3.89341215e-01, -1.39397116e+00,
#         1.66259625e+00, -3.99175002e-01,  1.06285616e-01, -6.36108721e-01,
#         6.84540618e-01, -1.84219940e+00,  1.72973991e+00, -6.98669907e-01,
#         1.17607425e-01, -5.58916041e-01,  5.37078407e-01,  2.17502255e+00,
#         1.44081364e+00, -6.61125356e-01, -1.98876977e+00, -5.35386701e-01,
#         4.11221323e-01, -8.53374358e-01,  9.36158146e-01,  2.97676848e-01,
#        -1.14000102e-01,  6.59711734e-01,  3.03849361e-01,  4.45396426e-01,
#         2.64605028e-01,  4.33290667e-01,  9.94529495e-02,  8.13985734e-01,
#        -8.04175574e-01,  2.33602706e+00,  2.48661652e-02, -4.26256845e-01,
#         6.57982622e-01,  4.64027544e-01,  2.30560930e+00,  1.31436581e-01,
#         5.56300789e-01,  1.90190682e+00,  1.52804461e+00, -3.36454255e-02,
#         3.84983005e-02,  2.39426263e-02,  1.62086283e-01,  2.31218052e-01,
#         7.91467329e-01, -1.16633068e+00,  3.17083975e-02, -5.67864633e-01,
#        -1.79227729e+00,  2.28490815e-01, -5.38381993e-01,  6.10257604e-01,
#        -4.55598603e-01,  1.18079932e+00,  7.61629581e-01, -1.87240271e-01,
#         1.23717663e-01,  1.64220717e-01, -7.90047475e-01, -1.01053348e+00,
#         4.11646521e-01, -9.65797678e-01, -1.08482850e-01, -8.18262222e-01,
#        -8.92949088e-01, -1.99327972e+00,  7.87052612e-01,  3.14623420e-01,
#        -1.07019314e+00,  1.13592179e-01, -3.44439029e-01,  1.01812774e+00,
#        -1.40045663e+00, -1.92316727e+00,  5.95842255e-01,  2.96291336e-01,
#         1.15705904e+00,  2.30658645e+00, -6.43500510e-01, -1.16243417e+00,
#        -7.21364779e-01,  9.04650274e-02,  2.76769889e-01,  3.91769323e-01,
#        -1.20692929e-01, -7.65110815e-01,  1.13213443e-01, -5.70075144e-01,
#        -5.81426141e-01,  8.88971838e-01, -9.76049205e-01,  7.27114133e-01,
#        -5.58384451e-01,  2.12328276e-01,  8.15019041e-01,  5.67081098e-01,
#        -8.73772015e-01,  5.51208638e-01,  3.09884802e-01,  9.14403000e-01,
#         7.94181889e-01, -4.95205747e-01,  9.15356820e-01,  9.86711548e-01,
#         1.24939240e+00, -1.27860667e+00,  5.71354866e-01,  1.79210489e+00,
#         1.43544800e+00,  1.41937968e+00,  2.32667206e-01,  5.73486474e-01,
#         8.94088973e-03,  2.02170595e+00, -2.58254549e-01,  8.05727942e-02,
#         6.63507063e-02,  6.71295050e-01, -5.21804581e-01,  5.23407073e-01,
#         4.65350697e-02,  7.78759680e-01,  1.12201565e+00, -4.68717734e-01,
#        -1.76703206e+00, -3.64475405e+00,  8.35640156e-01,  9.71268099e-01,
#         4.58180016e-01,  1.30028985e+00, -9.18987644e-03, -1.83506281e+00,
#         7.31350885e-01, -2.53548810e-01, -4.26064145e-01,  5.58034431e-01,
#        -4.12668556e-01, -3.08392708e-01, -9.07016234e-01,  3.80761389e-01,
#        -5.02990829e-01,  4.19805301e-01, -3.80045899e-01,  7.63694722e-01,
#        -1.10709377e+00,  1.08292737e+00, -1.13135529e+00, -8.38115865e-01,
#         2.63912307e-01, -1.62701785e+00,  6.68431196e-01, -3.40398276e-01,
#        -1.10503569e-01,  5.48094882e-01, -1.35863884e+00, -3.98932046e-01,
#         1.17862693e+00,  1.42421345e+00, -7.29502178e-01,  1.03865707e+00,
#        -4.01741652e-01, -4.72411948e-01, -3.10643592e-01, -2.61374242e-01,
#         8.27652417e-02, -1.17878945e+00,  1.99844632e-01,  3.14206115e-01,
#         8.40322560e-01,  6.04645627e-01, -9.81716415e-01, -6.41724880e-02,
#        -2.54085068e-01, -1.71956343e+00, -7.32060412e-01, -2.18096912e-01,
#         7.86528739e-01, -1.15711521e+00,  9.09426568e-01,  8.14335593e-01,
#         1.95345020e+00,  7.33996585e-01, -4.46685291e-01, -1.53575576e-01,
#         6.94161769e-01,  4.91954381e-02,  4.53709724e-01,  7.85222163e-01,
#         2.79463073e-01, -3.21027028e-01, -8.81012096e-01,  1.63261309e-01,
#        -1.71853386e+00,  2.56632899e+00,  3.51602364e-01,  3.71308984e-03,
#        -1.02111170e-01, -1.42098488e+00,  6.26744540e-01, -5.54171722e-01,
#         7.23090041e-01,  1.93118236e-01,  1.94854260e-02, -1.84912202e-01,
#        -1.10972146e-01,  3.05176018e-01,  8.78662818e-01,  2.95520971e-01])

# %%
plt.hist(data);

# %% [markdown]
# La función ``hist()`` tiene muchas opciones para ajustar tanto el cálculo como la visualización;

# %%
plt.hist(data, bins=30, density=True, alpha=0.5,    #bins=30  son los subgrupos que te forma 
         histtype='stepfilled', color='steelblue',
         edgecolor='none');

# %% [markdown]
# La combinación de ``histtype='stepfilled'`` junto con algo de transparencia ``alpha`` es muy útil a la hora de comparar histogramas de varias distribuciones:

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype='stepfilled', alpha=0.6, density=True, bins=40)

plt.hist(x1, **kwargs)  
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs);

# %% [markdown]
# Si desea simplemente calcular el histograma (es decir, contar el número de puntos en un intervalo determinado) y no mostrarlo, tiene a su disposición la función ``np.histogram()``:

# %%
counts, bin_edges = np.histogram(data, bins=5)
print(counts)
# Out:
# [ 65 380 419 124  12]

# %% [markdown]
# ## Histogramas bidimensionales y Binnings
#
# Al igual que creamos histogramas en una dimensión dividiendo la recta numérica en bins, también podemos crear histogramas en dos dimensiones dividiendo los puntos entre bins bidimensionales.
# Aquí veremos brevemente varias formas de hacerlo.
# Empezaremos definiendo algunos datos como una matriz ``x`` e ``y`` extraída de una distribución multivariante gaussiana:

# %%
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 10000).T

# %% [markdown]
# ### ``plt.hist2d``: Histograma bidimensional
#
# Una forma sencilla de trazar un histograma bidimensional es utilizar la función ``plt.hist2d`` de Matplotlib:

# %%
plt.hist2d(x, y, bins=30, cmap='Blues')
cb = plt.colorbar()
cb.set_label('counts in bin')

# %% [markdown]
# Al igual que ``plt.hist``, ``plt.hist2d`` tiene una serie de opciones adicionales para ajustar el gráfico y el binning, que se describen en la documentación de la función.

# %% [markdown]
# ### ``plt.hexbin``: Hexagonal binnings
#
# El histograma bidimensional crea un teselado de cuadrados a través de los ejes.
# Otra forma natural para tal teselación es el hexágono regular.
# Para este propósito, Matplotlib proporciona la rutina ``plt.hexbin``, que representa un conjunto de datos bidimensionales agrupados dentro de una rejilla de hexágonos:

# %%
plt.hexbin(x, y, gridsize=30, cmap='Blues')
cb = plt.colorbar(label='count in bin')

# %% [markdown]
# ### Estimación de la densidad del kernel
#
# Otro método común para evaluar densidades en múltiples dimensiones es la *estimación de la densidad del kernel* (KDE).
# KDE puede considerarse como una forma de "manchar" los puntos en el espacio y sumar el resultado para obtener una función suave.
# Existe una implementación de KDE extremadamente rápida y sencilla en el paquete ``scipy.stats``.
# He aquí un ejemplo rápido del uso de KDE con estos datos:

# %%
from scipy.stats import gaussian_kde

# ajustar una matriz de tamaño [Ndim, Nmuestras].
data = np.vstack([x, y])
kde = gaussian_kde(data)

# evaluar en una cuadrícula regular
xgrid = np.linspace(-3.5, 3.5, 40)
ygrid = np.linspace(-6, 6, 40)
Xgrid, Ygrid = np.meshgrid(xgrid, ygrid)
Z = kde.evaluate(np.vstack([Xgrid.ravel(), Ygrid.ravel()]))

# Trazar el resultado como una imagen
plt.imshow(Z.reshape(Xgrid.shape),
           origin='lower', aspect='auto',
           extent=[-3.5, 3.5, -6, 6],
           cmap='Blues')
cb = plt.colorbar()
cb.set_label("densidad")

# %% [markdown]
# <!--NAVIGATION-->
# < [Gráficos de densidad y contorno](4-Density_y_Contour_Plots.ipynb) | [Customizado de Legenda](6-Customizing_Legends.ipynb) >
