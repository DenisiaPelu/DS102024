# %% [markdown]
# # Tips

# %% [markdown]
# ### Paso 1. Importe las bibliotecas necesarias:

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# establecer el estilo seaborn en blanco

# %% [markdown]
# ### Paso 2. Importar el conjunto de datos de esta [dirección](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv).

# %%
df=pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/07_Visualization/Tips/tips.csv")
df.head()
# Out:
#    Unnamed: 0  total_bill   tip     sex smoker  day    time  size
# 0           0       16.99  1.01  Female     No  Sun  Dinner     2
# 1           1       10.34  1.66    Male     No  Sun  Dinner     3
# 2           2       21.01  3.50    Male     No  Sun  Dinner     3
# 3           3       23.68  3.31    Male     No  Sun  Dinner     2
# 4           4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Paso 3. Asignarlo a una variable llamada tips

# %%
tips=df.copy()

# %% [markdown]
# ### Paso 4. Trazar el histograma de la columna ``total_bill``

# %%
tips.columns
# Out:
# Index(['Unnamed: 0', 'total_bill', 'tip', 'sex', 'smoker', 'day', 'time',
#        'size'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
sns.histplot(tips['total_bill'], bins=20, kde=True, color='skyblue')
            
    # Agregar detalles al gráfico
plt.title(f'Histograma de {"total_bill"}', fontsize=14)
plt.xlabel('total_bill', fontsize=12)
plt.ylabel('Frecuencia', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### Paso 5. Cree un gráfico de dispersión que presente la relación entre ``total_bill`` y ``tip``

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=tips, x='total_bill', y='tip', alpha=0.6)
plt.title('grafico de dispersion entre  Score vs. members')
plt.xlabel('rating')
plt.ylabel('members')
plt.show()

# %% [markdown]
# ### Paso 6.  Crear una imagen con la relación de `total_bill`, `tip` y `size`.
# #### Sugerencia: es sólo una función.

# %%
df = sns.load_dataset('tips')

sns.scatterplot(data=df, x='total_bill', y='tip', hue='size', palette='viridis', size='size', sizes=(20, 200))

plt.title('Relación entre Total Bill, Tip y Size')
plt.xlabel('Total Bill')
plt.ylabel('Tip')

plt.show()

# %%
df = sns.load_dataset('tips')
cols = ['total_bill', 'tip', 'size']
sns.pairplot(df[cols], kind='scatter')

plt.show()

# %% [markdown]
# ### Paso 7. Presente la relación entre ``days`` y ``total_bill``

# %%
tips.columns
# Out:
# Index(['Unnamed: 0', 'total_bill', 'tip', 'sex', 'smoker', 'day', 'time',
#        'size'],
#       dtype='object')

# %%
sns.scatterplot(data=tips, x='day', y='total_bill')

plt.title('Relación entre Day y Total Bill')
plt.xlabel('Día de la semana')
plt.ylabel('Total Bill')

plt.show()

# %% [markdown]
# ### Paso 8. Crear un gráfico de dispersión con el ``day`` como eje y y ``tips`` como eje x, diferenciar los puntos por ``sex``.

# %%
sns.scatterplot(data=df, x='tip', y='day', hue='sex', palette='coolwarm')

plt.title('Relación entre Tip y Day, diferenciando por Sexo')
plt.xlabel('Tip')
plt.ylabel('Día de la Semana')

plt.legend(title='Sexo')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Paso 9.  Cree una box plot presentación del ``total_bill`` por ``day`` diferetiation el tiempo ``(Dinner or Lunch)``

# %%
sns.boxplot(data=df, x='day', y='total_bill', hue='time', palette='Set2')

plt.title('Distribución de Total Bill por Día de la Semana, Diferenciado por Tipo de Comida')
plt.xlabel('Día de la Semana')
plt.ylabel('Total Bill')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Paso 10. Cree dos histogramas del valor del tip basados en Dinner y Lunch. Deben estar uno al lado del otro.

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6), sharey=True)

sns.histplot(data=tips[tips['time'] == 'Dinner'], x='tip', kde=True, color='blue', ax=axes[0])
axes[0].set_title('Distribución de Propina para Dinner')
axes[0].set_xlabel('Tip')
axes[0].set_ylabel('Frecuencia')

sns.histplot(data=tips[tips['time'] == 'Lunch'], x='tip', kde=True, color='green', ax=axes[1])
axes[1].set_title('Distribución de Propina para Lunch')
axes[1].set_xlabel('Tip')
axes[1].set_ylabel('Frecuencia')

# Ajustar espacio entre los subgráficos
plt.tight_layout()

plt.show()

# %% [markdown]
# ### Paso 11. Cree dos gráficos de dispersión, uno para los hombres y otro para las mujeres, que presenten la relación entre el valor ``total_bill`` y la ``tip``, diferenciando entre ``smoker`` y ``no smoker``.
# ### Deben estar uno al lado del otro.

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6), sharey=True)

sns.scatterplot(data=tips[tips['sex'] == 'Male'], x='total_bill', y='tip', hue='smoker', palette='coolwarm', ax=axes[0])
axes[0].set_title('Relación entre Total Bill y Tip para Hombres')
axes[0].set_xlabel('Total Bill')
axes[0].set_ylabel('Tip')

sns.scatterplot(data=tips[tips['sex'] == 'Female'], x='total_bill', y='tip', hue='smoker', palette='coolwarm', ax=axes[1])
axes[1].set_title('Relación entre Total Bill y Tip para Mujeres')
axes[1].set_xlabel('Total Bill')
axes[1].set_ylabel('Tip')

plt.tight_layout()

plt.show()
